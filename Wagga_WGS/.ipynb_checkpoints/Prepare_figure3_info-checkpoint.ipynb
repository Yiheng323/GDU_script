# %% [markdown]
# This is a notebook to pull down all the information for figure 3 (ncbi hits). The design is to compair between each sample (barcode) instead of each flowcell as they sequenced the same thing. Therefore I just pulled all the ncbi hits for each flowcell for each barcode and merged them together according to the barcode.

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from itertools import product
import argparse
from ete3 import NCBITaxa

# %%
ncbi = NCBITaxa()

# %%
# use argparse to do this
#BASEDIR = args.BASEDIR
BASEDIR = '/home/yiheng/data/20170617_FAH05432'

# here we define the folder name of the dataframe it created by capturing the folder from the BASDIR
folder_name = os.path.basename(BASEDIR)
column_name = folder_name.split('_')[-1]

# %%
# first check if the analysis folder is there
folder_list = 'analysis  basecalled_data  scripts  tracking  workspace'.split(' ')
for x in range(0,folder_list.count('')):
    folder_list.remove('')
#fix this test
if not set(os.listdir(os.path.abspath(BASEDIR))) == set (folder_list):
    print("Something wrong with basefolder. check it please.")

# %%
# get the dataframe there
dataframe = os.path.join(BASEDIR, 'analysis', 'summary_df_%s.tab' % folder_name)
sum_df = pd.read_csv(dataframe, sep='\t')
# Out:
# /home/yiheng/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1,2,3,5,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sum_df.columns
# Out:
# Index(['read_id', 'passes_filtering', 'sequence_length_template',
#        'mean_qscore_template', 'barcode_arrangement', 'barcode_score', 'kit',
#        'variant', 'pc_survived', 'nl_survived', 'qseqid_rg', 'sseqid_rg',
#        'evalue_rg', 'length_rg', 'pident_rg', 'nident_rg', 'sacc_rg',
#        'staxids_rg', 'scomnames_rg', 'read_length_pc_x', 'qseqid_nt',
#        'sseqid_nt', 'evalue_nt', 'length_nt', 'pident_nt', 'nident_nt',
#        'sacc_nt', 'staxids_nt', 'scomnames_nt', 'read_length_pc_y'],
#       dtype='object')

# %%
# fills the nan with T/F for easier handling
sum_df.sseqid_rg.fillna(False, inplace=True)
sum_df.sseqid_nt.fillna(False, inplace=True)
# filter out the rg blast hit
ntblasthit_reads = sum_df[(sum_df.sseqid_rg == False) & (sum_df.sseqid_nt != False) & (sum_df.passes_filtering == True) & (sum_df.pc_survived == True) & (sum_df.nl_survived == True)]
pd.set_option('display.max_columns', None)

#Removing unncessary columns from joint_NCBI_df_taxonomy
#I hard coded to select as it depends on what information you need
for columns in ['passes_filtering', 
       'mean_qscore_template', 'barcode_score', 'kit',
       'variant', 'pc_survived', 'nl_survived', 'qseqid_rg', 'sseqid_rg',
       'evalue_rg', 'length_rg', 'pident_rg', 'nident_rg', 'sacc_rg',
       'staxids_rg', 'scomnames_rg', 'read_length_pc_x', 'qseqid_nt',
       'sseqid_nt', 'evalue_nt', 'length_nt', 'pident_nt', 'nident_nt',
       'sacc_nt','scomnames_nt', 'read_length_pc_y']:
    del ntblasthit_reads[columns]

# %%
###########This block for barcodes order
# now everything left is what we want to plot out
# arrange different barcodes
# REMEMBER: This need to be manual check:
# barcode01 is Pst infected sample, barcode02 is Zymo sample, 03 is nill sample, 04 is co-infection sample and 05 is Pyre sample
new_barcodes = ['barcode01', 'barcode02', 'barcode03', 'barcode04', 'barcode05']
if column_name == 'run1':
    ntblasthit_barcode01 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode02']
    ntblasthit_barcode02 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode06']
    ntblasthit_barcode03 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode04']
    ntblasthit_barcode04 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode05']
    ntblasthit_barcode05 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode03']
    ntblasthit_barcode01.barcode_arrangement = ntblasthit_barcode01.barcode_arrangement.replace(to_replace='barcode02', value='barcode01')
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('barcode07')], inplace = True)
    ntblasthit_barcode01.barcode_arrangement = ntblasthit_barcode01.barcode_arrangement.replace(to_replace='barcode03', value='barcode07')
    ntblasthit_barcode01.barcode_arrangement = ntblasthit_barcode01.barcode_arrangement.replace(to_replace='barcode06', value='barcode02')
    ntblasthit_barcode01.barcode_arrangement = ntblasthit_barcode01.barcode_arrangement.replace(to_replace='barcode04', value='barcode03')
    ntblasthit_barcode01.barcode_arrangement = ntblasthit_barcode01.barcode_arrangement.replace(to_replace='barcode05', value='barcode04')
    ntblasthit_barcode01.barcode_arrangement = ntblasthit_barcode01.barcode_arrangement.replace(to_replace='barcode07', value='barcode05')

elif column_name == 'run2':
    # first delete the rows that contains the barcode we are going to replace
    # I think maybe better to first adjust the df to get rid of all the mis/unclassified reads so the df get smaller
    # and we do not need those reads for plotting
    
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('barcode01')], inplace = True)
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('barcode02')], inplace = True)
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('barcode03')], inplace = True)
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('barcode04')], inplace = True)
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('barcode05')], inplace = True)
    ntblasthit_reads.drop(ntblasthit_reads.index[ntblasthit_reads.barcode_arrangement.str.contains('unclassified')], inplace = True)
    old_barcodes = ['barcode07', 'barcode08', 'barcode09', 'barcode10', 'barcode11']
    for old_barcode, new_barcode in zip(old_barcodes, new_barcodes):
        ntblasthit_reads.loc\
        [ntblasthit_reads[ntblasthit_reads['barcode_arrangement'] == old_barcode].index,'barcode_arrangement']\
        = [new_barcode]
    #ntblasthit_reads['barcode_arrangement'] = ntblasthit_reads.barcode_arrangement.replace(to_replace='barcode07', value='barcode01')

    
elif column_name == 'FAH05432':
    ntblasthit_barcode01 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode01']
    ntblasthit_barcode02 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode02']
    ntblasthit_barcode03 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode03']
    ntblasthit_barcode04 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode04']
    ntblasthit_barcode05 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode05']
elif column_name == 'FAH05731':
    ntblasthit_barcode01 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode01']
    ntblasthit_barcode02 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode02']
    ntblasthit_barcode03 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode03']
    ntblasthit_barcode04 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode04']
    ntblasthit_barcode05 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement == 'barcode05']
else:
    pass

# %%
# now just filter out all the reads that are not going to used for ploting
ntblasthit_reads_barcode01 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement.str.contains('barcode01')]
ntblasthit_reads_barcode02 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement.str.contains('barcode02')]
ntblasthit_reads_barcode03 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement.str.contains('barcode03')]
ntblasthit_reads_barcode04 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement.str.contains('barcode04')]
ntblasthit_reads_barcode05 = ntblasthit_reads[ntblasthit_reads.barcode_arrangement.str.contains('barcode05')]

# now concat them together. but remember that the index has to change to add the column for ncbi taxa
ntblasthit_reads_filtered_barcodes = pd.concat([ntblasthit_reads_barcode01, 
                                                ntblasthit_reads_barcode02, 
                                                ntblasthit_reads_barcode03, 
                                                ntblasthit_reads_barcode04, 
                                                ntblasthit_reads_barcode05], ignore_index=True)

# %%
# as the concate before will result the staxid into a string
# so now change the string back to float so it can be recognized by the NCBITaxa
for taxid in ntblasthit_reads_filtered_barcodes['staxids_nt']:
    if ';' in str(taxid):
        taxid = taxid.split(';')[0]
    else:
        pass
    float(taxid)

# %%
#Function to generate taxonomy columns based on NCBITaxa results for NCBI hit dataframe, 
def search_rank_output_name_append_column(df, staxid_column, rank_search):
    """Input df, staxid_column from same df and rank_search (a desired taxonomic rank 
    from each staxid's lineage), outputs taxonomic name corresponding to rank_search or 'Unclassified' if
    unavailable and appends to df row by row"""
    rank_list = []
    for read_index in range(0, len(staxid_column)):
        taxid = ''
        if ';' in str(staxid_column[read_index]):
            taxid = staxid_column[read_index].split(';')[0]
        else:
            taxid = staxid_column[read_index]
        
        taxid_lineage = ''
        taxid_lineage = ncbi.get_lineage(taxid)
        
        names = ''
        names = ncbi.get_taxid_translator(taxid_lineage)
        
        ranks = ''
        ranks = ncbi.get_rank(taxid_lineage) #Dict
        
        ranks2names = ''
        ranks2names = {ranks[k]:names[k] for k in names.keys() & ranks}
        
        if rank_search in ranks2names.keys():
            rank_list.append(ranks2names[rank_search])#if rank in dict, print name
        else:
            rank_list.append('Unclassified')
    df[rank_search] = rank_list
# NOTE: Appending is always slow, try and find a better way e.g df.apply to a column based on staxids column

# %%
#ntblasthit_reads_filtered_barcodes_added_TaxaRank = ntblasthit_reads_filtered_barcodes.copy()
rank_list = ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']
for rank in rank_list:
    search_rank_output_name_append_column(ntblasthit_reads_filtered_barcodes, 
                                          ntblasthit_reads_filtered_barcodes.staxids_nt, 
                                          rank)

# %%
ntblasthit_reads_filtered_barcodes
# Out:
#                                    read_id sequence_length_template  \
# 0     807a8997-b021-4820-b33a-1b9095249dc7                     2695
# 1     c53fa9c8-f4d5-4876-8526-e04fcea0ac5d                     3286
# 2     19a62259-0925-41ef-94e4-6fe9ef776c81                     2455
# 3     7e4e83ba-26fa-4d0b-b714-724976a9c7a7                     2347
# 4     c92e3d57-c554-4d73-9e17-a51bc14aa4d4                     3210
# 5     072bbc16-20a5-45b8-bcbf-e7239f48ed12                     3164
# 6     7eb68975-bd44-40da-b0e8-2635fcedfbb0                     2892
# 7     f876c268-fe76-4fb7-97e7-e3c6fa2d8c8b                     3054
# 8     2143605b-7298-43af-b034-400dd381acc7                     2512
# 9     00f1b4d2-cc23-4231-9b51-543873ddddd2                     3047
# 10    74885d13-7285-4de6-ae85-89a8927c36ab                     2751
# 11    fe662e8d-bb9d-45d5-b699-7891406c5df4                     1916
# 12    d5533aed-db93-4957-928a-60cd6caa2d0f                     2941
# 13    2b27f02a-bd3c-4c0d-a4fb-7e1575c76fe0                     2138
# 14    d6a81cd2-3423-4242-9cb3-84f81be34892                     2143
# 15    2828d03d-7417-46c5-8382-792e21003d99                     3452
# 16    f7760040-5944-4aec-9d3f-b98389bda403                      415
# 17    fa63e5c1-71b2-42e9-906d-879ad1ad4f3b                     3081
# 18    be038069-e219-48b3-8352-a70beaa767e0                     2375
# 19    f31b2c3c-87ba-4957-a72c-dd8126a70476                     1778
# 20    52767e8d-6540-439b-a930-bb5f8ece7bb8                     1981
# 21    b89419aa-7906-4bdb-ad6d-06bd26e65944                     2161
# 22    6047063f-eb37-4ef4-a9b0-304ced98946e                     3141
# 23    af09a516-1d55-4685-8bf6-dba8d13eb50e                      728
# 24    b0ded9cf-3b68-4dbb-b12c-c7e8b18dd35e                     3073
# 25    8e937eda-6ba6-4f1c-b5ea-fd9f3690ac2c                     2018
# 26    ec446ef2-0236-4dc3-a8db-29dcf2a4d5f8                     3006
# 27    502dab27-225d-4462-ab53-5572a4ff7d46                     2049
# 28    0d733956-7720-40c7-9ab0-19842a016005                     2015
# 29    c77016d6-1b7f-49f7-8c4b-6c7ca171b291                     2332
# ...                                    ...                      ...
# 6030  036f16cc-2e7a-4414-94a2-55b80e502345                     2046
# 6031  3febc7c5-f308-4f64-9b37-bc2357608d43                      926
# 6032  2de9f0c0-1338-4978-9f88-f34336e3c16d                     3216
# 6033  1c4cf73a-df25-4eb8-a96d-dfa117243cb0                     2046
# 6034  f0f4e05a-7bf0-4eeb-9a0a-5b84c6590bc2                     2568
# 6035  b109ccf5-048d-45e6-a0c1-e568d4498b66                     2575
# 6036  00cb05e4-9dcc-4562-97b6-1d34db28b2ce                      699
# 6037  0be8c7f8-9da2-4d6c-84bc-4852d29a23ff                     3670
# 6038  4e1bc3af-c37e-44be-82e4-765000b17887                     2376
# 6039  54b4c516-a392-4c67-bc3f-20d9cb08dfd1                     3185
# 6040  e15f756e-f926-4da7-bc99-2a1b94308bf9                     5388
# 6041  5dfeeb74-f577-4706-bc10-4173ea8c13d4                     3439
# 6042  248cff4b-734e-402d-95ba-aeda3dfd5a78                     3337
# 6043  434bf795-fa15-4709-872e-fea2f0bf28fa                      860
# 6044  0e196992-8736-4a23-a766-b6a48ac53f92                      443
# 6045  3422c128-320c-40a4-8f54-8df22e42117e                     2227
# 6046  afe0dea5-5835-41ad-a3d5-0111885fadb4                     4887
# 6047  74af4e06-3343-446c-8d5d-4b0904a192fe                     2957
# 6048  b734a7f7-1c8f-4dcf-a175-702a74f07473                     3285
# 6049  7e83c505-957c-43a7-bd2f-8921b8bacede                     2764
# 6050  9607245c-061a-4f58-8d18-a93d2b3e8cdc                     2592
# 6051  9a4c0335-3fbf-4b16-ac09-a346b6365978                     1834
# 6052  f6d6b97e-9204-41ef-9e43-2126f7dd8557                      351
# 6053  a9dab824-a355-4c7d-bad8-9f46ad5db179                     2552
# 6054  032c2734-9254-49df-b949-f21606858835                     2109
# 6055  59353f77-87ee-40a0-930f-328719e2bfe4                     2592
# 6056  86bf9dba-4728-463d-b767-231f0863ebea                     2595
# 6057  88013815-813d-4f85-833c-2d5d0f647a94                     3832
# 6058  62375b9c-54db-4097-95af-4bd20c723822                     2544
# 6059  7f21fa02-74cf-4d6e-896d-76ebc4773042                     3987
#
#      barcode_arrangement   staxids_nt superkingdom          phylum  \
# 0              barcode01       200451     Bacteria  Proteobacteria
# 1              barcode01       200451     Bacteria  Proteobacteria
# 2              barcode01       192087     Bacteria  Proteobacteria
# 3              barcode01       200451     Bacteria  Proteobacteria
# 4              barcode01       192087     Bacteria  Proteobacteria
# 5              barcode01          321     Bacteria  Proteobacteria
# 6              barcode01          552     Bacteria  Proteobacteria
# 7              barcode01  1.28236e+06     Bacteria  Proteobacteria
# 8              barcode01        48100    Eukaryota      Ascomycota
# 9              barcode01       634500     Bacteria  Proteobacteria
# 10             barcode01  1.50567e+06    Eukaryota   Basidiomycota
# 11             barcode01       192087     Bacteria  Proteobacteria
# 12             barcode01       199201     Bacteria  Proteobacteria
# 13             barcode01       889211     Bacteria  Proteobacteria
# 14             barcode01       192087     Bacteria  Proteobacteria
# 15             barcode01       192087     Bacteria  Proteobacteria
# 16             barcode01       587753     Bacteria  Proteobacteria
# 17             barcode01       665914     Bacteria  Proteobacteria
# 18             barcode01       192087     Bacteria  Proteobacteria
# 19             barcode01       199201     Bacteria  Proteobacteria
# 20             barcode01  1.32493e+06     Bacteria  Proteobacteria
# 21             barcode01        35703     Bacteria  Proteobacteria
# 22             barcode01       418459    Eukaryota   Basidiomycota
# 23             barcode01       192087     Bacteria  Proteobacteria
# 24             barcode01  1.32493e+06     Bacteria  Proteobacteria
# 25             barcode01       465817     Bacteria  Proteobacteria
# 26             barcode01       199201     Bacteria  Proteobacteria
# 27             barcode01  1.28236e+06     Bacteria  Proteobacteria
# 28             barcode01       192087     Bacteria  Proteobacteria
# 29             barcode01  1.32493e+06     Bacteria  Proteobacteria
# ...                  ...          ...          ...             ...
# 6030           barcode05        48100    Eukaryota      Ascomycota
# 6031           barcode05          317     Bacteria  Proteobacteria
# 6032           barcode05       341663    Eukaryota      Ascomycota
# 6033           barcode05       398673    Eukaryota      Ascomycota
# 6034           barcode05        76761     Bacteria  Proteobacteria
# 6035           barcode05   1.6036e+06    Eukaryota      Arthropoda
# 6036           barcode05       169297    Eukaryota    Streptophyta
# 6037           barcode05        48100    Eukaryota      Ascomycota
# 6038           barcode05        45151    Eukaryota      Ascomycota
# 6039           barcode05  1.32493e+06     Bacteria  Proteobacteria
# 6040           barcode05       112498    Eukaryota      Ascomycota
# 6041           barcode05       671987    Eukaryota      Ascomycota
# 6042           barcode05        29760    Eukaryota    Streptophyta
# 6043           barcode05         4565    Eukaryota    Streptophyta
# 6044           barcode05         7165    Eukaryota      Arthropoda
# 6045           barcode05        51953    Eukaryota    Streptophyta
# 6046           barcode05          562     Bacteria  Proteobacteria
# 6047           barcode05        39946    Eukaryota    Streptophyta
# 6048           barcode05         5599    Eukaryota      Ascomycota
# 6049           barcode05       930090    Eukaryota      Ascomycota
# 6050           barcode05         7955    Eukaryota        Chordata
# 6051           barcode05         4999    Eukaryota   Basidiomycota
# 6052           barcode05         7955    Eukaryota        Chordata
# 6053           barcode05       353152    Eukaryota     Apicomplexa
# 6054           barcode05       741155     Bacteria  Proteobacteria
# 6055           barcode05        48100    Eukaryota      Ascomycota
# 6056           barcode05         5599    Eukaryota      Ascomycota
# 6057           barcode05       930090    Eukaryota      Ascomycota
# 6058           barcode05        33069     Bacteria  Proteobacteria
# 6059           barcode05      1785145     Bacteria  Proteobacteria
#
#                     class             order              family  \
# 0     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 1     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 2     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 3     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 4     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 5     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 6     Gammaproteobacteria  Enterobacterales         Erwiniaceae
# 7     Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 8         Dothideomycetes      Pleosporales       Pleosporaceae
# 9     Gammaproteobacteria  Enterobacterales         Erwiniaceae
# 10        Pucciniomycetes       Pucciniales        Pucciniaceae
# 11    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 12    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 13    Gammaproteobacteria  Enterobacterales         Erwiniaceae
# 14    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 15    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 16    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 17    Gammaproteobacteria  Enterobacterales         Erwiniaceae
# 18    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 19    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 20    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 21    Gammaproteobacteria  Enterobacterales  Enterobacteriaceae
# 22        Pucciniomycetes       Pucciniales        Pucciniaceae
# 23    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 24    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 25    Gammaproteobacteria  Enterobacterales         Erwiniaceae
# 26    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 27    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 28    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 29    Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# ...                   ...               ...                 ...
# 6030      Dothideomycetes      Pleosporales       Pleosporaceae
# 6031  Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 6032       Eurotiomycetes        Eurotiales      Aspergillaceae
# 6033      Sordariomycetes       Hypocreales        Hypocreaceae
# 6034  Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 6035              Insecta         Hemiptera        Pentatomidae
# 6036           Liliopsida            Poales             Poaceae
# 6037      Dothideomycetes      Pleosporales       Pleosporaceae
# 6038      Dothideomycetes      Pleosporales       Pleosporaceae
# 6039  Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 6040      Dothideomycetes       Capnodiales  Mycosphaerellaceae
# 6041      Dothideomycetes      Pleosporales       Pleosporaceae
# 6042         Unclassified           Vitales            Vitaceae
# 6043           Liliopsida            Poales             Poaceae
# 6044              Insecta           Diptera           Culicidae
# 6045           Liliopsida          Arecales           Arecaceae
# 6046  Gammaproteobacteria  Enterobacterales  Enterobacteriaceae
# 6047           Liliopsida            Poales             Poaceae
# 6048      Dothideomycetes      Pleosporales       Pleosporaceae
# 6049      Dothideomycetes      Pleosporales       Pleosporaceae
# 6050          Actinopteri     Cypriniformes          Cyprinidae
# 6051      Tremellomycetes       Tremellales   Cuniculitremaceae
# 6052          Actinopteri     Cypriniformes          Cyprinidae
# 6053          Conoidasida    Eucoccidiorida   Cryptosporidiidae
# 6054  Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 6055      Dothideomycetes      Pleosporales       Pleosporaceae
# 6056      Dothideomycetes      Pleosporales       Pleosporaceae
# 6057      Dothideomycetes      Pleosporales       Pleosporaceae
# 6058  Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
# 6059  Gammaproteobacteria   Pseudomonadales    Pseudomonadaceae
#
#                 genus                       species
# 0         Pseudomonas              Pseudomonas poae
# 1         Pseudomonas              Pseudomonas poae
# 2         Pseudomonas          Pseudomonas syringae
# 3         Pseudomonas              Pseudomonas poae
# 4         Pseudomonas          Pseudomonas syringae
# 5         Pseudomonas          Pseudomonas syringae
# 6             Erwinia             Erwinia amylovora
# 7         Pseudomonas              Pseudomonas poae
# 8          Alternaria             Alternaria solani
# 9             Erwinia            Erwinia billingiae
# 10           Puccinia   Puccinia cf. psidii AE-2014
# 11        Pseudomonas          Pseudomonas syringae
# 12        Pseudomonas          Pseudomonas syringae
# 13            Erwinia             Erwinia amylovora
# 14        Pseudomonas          Pseudomonas syringae
# 15        Pseudomonas          Pseudomonas syringae
# 16        Pseudomonas      Pseudomonas chlororaphis
# 17            Pantoea              Pantoea gaviniae
# 18        Pseudomonas          Pseudomonas syringae
# 19        Pseudomonas          Pseudomonas syringae
# 20        Pseudomonas          Pseudomonas syringae
# 21        Citrobacter      Citrobacter amalonaticus
# 22           Puccinia             Puccinia graminis
# 23        Pseudomonas          Pseudomonas syringae
# 24        Pseudomonas          Pseudomonas syringae
# 25            Erwinia          Erwinia tasmaniensis
# 26        Pseudomonas          Pseudomonas syringae
# 27        Pseudomonas              Pseudomonas poae
# 28        Pseudomonas          Pseudomonas syringae
# 29        Pseudomonas          Pseudomonas syringae
# ...               ...                           ...
# 6030       Alternaria             Alternaria solani
# 6031      Pseudomonas          Pseudomonas syringae
# 6032      Aspergillus           Aspergillus terreus
# 6033      Trichoderma            Trichoderma gamsii
# 6034      Pseudomonas           Pseudomonas veronii
# 6035         Cressona                 Cressona rufa
# 6036         Aegilops             Aegilops tauschii
# 6037       Alternaria             Alternaria solani
# 6038      Pyrenophora  Pyrenophora tritici-repentis
# 6039      Pseudomonas          Pseudomonas syringae
# 6040        Ramularia         Ramularia collo-cygni
# 6041      Exserohilum          Exserohilum turcicum
# 6042            Vitis                Vitis vinifera
# 6043         Triticum             Triticum aestivum
# 6044        Anopheles             Anopheles gambiae
# 6045           Elaeis             Elaeis guineensis
# 6046      Escherichia              Escherichia coli
# 6047            Oryza                  Oryza sativa
# 6048       Alternaria          Alternaria alternata
# 6049        Bipolaris              Bipolaris oryzae
# 6050            Danio                   Danio rerio
# 6051      Kockovaella         Kockovaella imperatae
# 6052            Danio                   Danio rerio
# 6053  Cryptosporidium        Cryptosporidium parvum
# 6054      Pseudomonas       Pseudomonas alcaliphila
# 6055       Alternaria             Alternaria solani
# 6056       Alternaria          Alternaria alternata
# 6057        Bipolaris              Bipolaris oryzae
# 6058      Pseudomonas       Pseudomonas viridiflava
# 6059      Pseudomonas         Pseudomonas sp. MS586
#
# [6060 rows x 11 columns]

# %%
# add the flowcell column just in case
ntblasthit_reads_filtered_barcodes = ntblasthit_reads_filtered_barcodes.assign(Flowcell = column_name)

# %%
ntblasthit_reads_filtered_barcodes.to_csv(r'/home/yiheng/analysis/WGS/%s_taxa.tab' % column_name, header=column_name, index=None, sep='\t')

# %%
#Defines a function to make manual adjustments to the NCBI taxonomic sorting
def manually_adjust_ncbi_taxonomy(rank_select, entry_select, ranks_to_edit, new_entry):
    """Select dataframe entries to edit by a specific rank (rank_select) 
    and entry related to that rank (entry_select), 
    provide a list of ranks to edit for those selected entries (ranks_to_edit),
    replace these ranks with a new entry (new_entry)"""
    if entry_select in list(ntblasthit_reads_filtered_barcodes[rank_select].unique()):
        selection = (ntblasthit_reads_filtered_barcodes[rank_select] == entry_select)
        selected_tax_ranks = ranks_to_edit
        for ranks in selected_tax_ranks:
            ntblasthit_reads_filtered_barcodes[ranks][selection] = new_entry

# %%
manually_adjust_ncbi_taxonomy('species', 
                            'Cloning vector lambda TXF97', 
                            ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus'], 
                            'Cloning vector lambda TXF97')

manually_adjust_ncbi_taxonomy('superkingdom', 
                            'Viruses', 
                            ['phylum', 'class'], 
                            'dsDNA viruses, no RNA stage')

# %%
#count pivot table of dataframe with taxonomic columns: 
#rows - rank names, columns - barcode, sorted by desired class
def generate_ncbi_taxonomy_pivot(tax_df, rank, bcs, num):
    """From tax_df, generate a pivot table listing num rank counts, sorted by bcs"""
    pivot_table = tax_df.pivot_table(values='order', 
                                            index=rank, 
                                            columns='barcode_arrangement', 
                                            aggfunc='count', 
                                            fill_value=0, 
                                            margins=True)
    pivot_table.columns.name = None
    return pivot_table.sort_values(bcs, axis=0, ascending=False).head(n=num)

# %%
generate_ncbi_taxonomy_pivot(ntblasthit_reads_filtered_barcodes, 'family','barcode04',20)
# Out:
#                      barcode01  barcode02  barcode03  barcode04  barcode05  \
# family
# All                       1942       1855         37       1748        271
# Pseudomonadaceae          1470        814          0       1104         58
# Pleosporaceae               44        263          1        160         77
# Sphingomonadaceae            1        161          0         83          1
# Mycosphaerellaceae           1        103          0         43          2
# Hymenobacteraceae            1         82          0         39          0
# Enterobacteriaceae          51         56         10         35          5
# Microbacteriaceae            3         37          0         31          0
# Poaceae                     14          8         13         29         41
# Leptosphaeriaceae            7         34          1         18         17
# Oxalobacteraceae            16         18          0         15          0
# Erwiniaceae                165          7          0         13          0
# Unclassified                 6         20          0         10          1
# Cryptococcaceae              2          6          0          7          8
# Burkholderiaceae             2          5          0          7          1
# Pucciniaceae                56          0          0          6          0
# Nocardiaceae                 2         33          0          6          0
# Sporidiobolaceae             2          1          0          5          3
# Paenibacillaceae             1          7          0          5          0
# Sphingobacteriaceae          0          2          0          5          0
#
#                       All
# family
# All                  5853
# Pseudomonadaceae     3446
# Pleosporaceae         545
# Sphingomonadaceae     246
# Mycosphaerellaceae    149
# Hymenobacteraceae     122
# Enterobacteriaceae    157
# Microbacteriaceae      71
# Poaceae               105
# Leptosphaeriaceae      77
# Oxalobacteraceae       49
# Erwiniaceae           185
# Unclassified           37
# Cryptococcaceae        23
# Burkholderiaceae       15
# Pucciniaceae           62
# Nocardiaceae           41
# Sporidiobolaceae       11
# Paenibacillaceae       13
# Sphingobacteriaceae     7

# %%
# % pivot table of dataframe with taxonomic columns: 
#rows - rank names, columns - barcode, sorted by desired class
def generate_ncbi_taxonomy_pivot_pc(tax_df, rank, bcs, num):
    """From tax_df, generate a pivot table listing num rank %, sorted ascending by bcs"""
    pivot_table_pc = tax_df.pivot_table(values='order', 
                                            index=rank, 
                                            columns='barcode_arrangement', 
                                            aggfunc='count', 
                                            fill_value=0, 
                                            margins=True)
    pivot_table_pc.columns.name = None
    
    for brcs in pivot_table_pc.columns:
        pivot_table_pc[str(brcs) + '%'] = pivot_table_pc[brcs].apply(lambda x: (x / pivot_table_pc[brcs].loc['All'])*100)
    for brcs in pivot_table_pc.columns:
        if '%' not in brcs:
            pivot_table_pc.drop(brcs, axis=1, inplace=True)
    pivot_table_pc.drop('All', axis=0, inplace=True)

    pivot_table_pc2 = pivot_table_pc.sort_values(str(bcs) + '%', axis=0, ascending=False)
    return pivot_table_pc2.applymap(lambda x: '%.3f' % x).head(n=num)

# %%
generate_ncbi_taxonomy_pivot_pc(ntblasthit_reads_filtered_barcodes, 'genus', 'barcode04', 20)
# Out:
#                   barcode01% barcode02% barcode03% barcode04% barcode05%  \
# genus
# Pseudomonas           75.695     43.881      0.000     63.158     21.402
# Alternaria             1.442     11.321      2.703      7.037     20.295
# Sphingomonas           0.051      7.925      0.000      4.291      0.369
# Zymoseptoria           0.051      5.337      0.000      2.346      0.000
# Hymenobacter           0.051      4.420      0.000      2.231      0.000
# Escherichia            0.566      2.426     24.324      1.716      1.476
# Bipolaris              0.412      1.456      0.000      1.201      4.059
# Curtobacterium         0.051      0.755      0.000      1.144      0.000
# Leptosphaeria          0.360      1.833      2.703      1.030      6.273
# Triticum               0.309      0.108     29.730      0.973     14.022
# Unclassified           0.463      0.485      0.000      0.858      0.369
# Pantoea                1.493      0.216      0.000      0.744      0.000
# Setosphaeria           0.206      0.431      0.000      0.629      1.107
# Massilia               0.360      0.431      0.000      0.458      0.000
# Frondihabitans         0.000      0.270      0.000      0.400      0.000
# Aegilops               0.154      0.108      0.000      0.400      0.738
# Puccinia               2.781      0.000      0.000      0.343      0.000
# Rhodococcus            0.103      1.725      0.000      0.343      0.000
# Janthinobacterium      0.309      0.377      0.000      0.343      0.000
# Rhodotorula            0.103      0.054      0.000      0.286      1.107
#
#                      All%
# genus
# Pseudomonas        58.876
# Alternaria          7.125
# Sphingomonas        3.827
# Zymoseptoria        2.409
# Hymenobacter        2.084
# Escherichia         1.691
# Bipolaris           1.145
# Curtobacterium      0.598
# Leptosphaeria       1.316
# Triticum            1.264
# Unclassified        0.581
# Pantoea             0.786
# Setosphaeria        0.444
# Massilia            0.393
# Frondihabitans      0.205
# Aegilops            0.239
# Puccinia            1.025
# Rhodococcus         0.683
# Janthinobacterium   0.325
# Rhodotorula         0.188

# %%
#Assesses number of barcodes, generates necessary number of plots (even) and relevant indexing system
ncbiblast_barcodes = list(ntblasthit_reads_filtered_barcodes['barcode_arrangement'].unique())
no_of_subplots = len(ncbiblast_barcodes)+1

# %%
#Always 2 columns, bc-count/2 rows 
no_of_subplots_pair = [int(no_of_subplots/2), 2]

#Produce pairs of indices correlating to the coordinates of the subplots
subplot_coordinates = list(product(range(no_of_subplots_pair[0]), range(no_of_subplots_pair[1])))
subplot_coordinates_list = [list(l) for l in subplot_coordinates]
subplot_coordinates_list_rows = [i[0] for i in subplot_coordinates_list]
subplot_coordinates_list_columns = [i[1] for i in subplot_coordinates_list]

fig, ax = plt.subplots(no_of_subplots_pair[1], no_of_subplots_pair[0], figsize=(20, 6))

# %%
name_list = ['Stripe rust', 'Septoria tritici blotch', 'Healthy wheat', 'Stripe rust and sptoria tritici blotch', 'Yellow spot']

# %%
def get_color(x):
    x = x%10
    return ('#%02X%02X%02X' % (int(plt.cm.tab10.colors[x][0]*255),int(plt.cm.tab10.colors[x][1]*255),int(plt.cm.tab10.colors[x][2]*255)))

def applyTaxPlotStyle(ax_ind1, ax_ind2, bcs, rank, name):
    labels = ''
    labels = tuple(generate_ncbi_taxonomy_pivot_pc(ntblasthit_reads_filtered_barcodes, rank, bcs, 10)[bcs + '%'].index)
    y_pos = ''
    y_pos = np.arange(len(labels))
    sizes = ''
    sizes = tuple([float(i) for i in generate_ncbi_taxonomy_pivot_pc(ntblasthit_reads_filtered_barcodes, rank, bcs, 10)[bcs + '%']])
    
    ax[ax_ind1, ax_ind2].barh(y_pos, sizes, align='center', alpha=0.4, color=get_color(2*ax_ind2 + ax_ind1))
    ax[ax_ind1, ax_ind2].set_yticks(y_pos)
    ax[ax_ind1, ax_ind2].set_yticklabels(labels)
    ax[ax_ind1, ax_ind2].tick_params(top="off", right="off", left="off")
    ax[ax_ind1, ax_ind2].set_xlabel('% Total Reads Hitting NCBI')
    ax[ax_ind1, ax_ind2].set_xticks(range(0, 110, 10))
    ax[ax_ind1, ax_ind2].set_title(name)
    ax[ax_ind1, ax_ind2].invert_yaxis()
    ax[ax_ind1, ax_ind2].grid(b=None, which='major', axis='x', linestyle='dashed', linewidth=0.2)
    ax[ax_ind1, ax_ind2].annotate('E = 0.00001', 
             xy=(1.06, 0.3), xycoords='axes fraction', fontsize=10, xytext=(-20, -30), textcoords='offset points', 
             ha='right', va='bottom')

    
def generateTaxSubplots(search_rank):
    for ax_ind1, ax_ind2, bcs, name in zip(subplot_coordinates_list_columns, subplot_coordinates_list_rows, ncbiblast_barcodes, name_list):
        applyTaxPlotStyle(ax_ind1, ax_ind2, bcs, search_rank, name)    

    if len(list(ntblasthit_reads_filtered_barcodes['barcode_arrangement'].unique())) != 0:
        plt.delaxes(ax[subplot_coordinates_list_columns[-1], subplot_coordinates_list_rows[-1]])
    
    plt.suptitle('Reads Hitting NCBI Database - % By ' + str(search_rank).title() + ' By Sample', 
             fontsize='x-large',
             y=1.02,
             fontweight="bold")
    
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1.4, hspace=0.4)
    plt.tight_layout()
    
    plt.savefig('/home/yiheng/analysis/WGS/figures' + 'figure3_%s_%s.png' % (column_name, search_rank), bbox_inches='tight', dpi=1000)
    plt.show()

# %%
fig, ax = plt.subplots(no_of_subplots_pair[1], no_of_subplots_pair[0], figsize=(20, 6))
generateTaxSubplots('genus')

# %%
df1=pd.DataFrame([[1, 2],[10, 1], [3, 4], [7, 8]], columns=['A', 'B'])
df2=pd.DataFrame([[1, 4],[3, 5]], columns=['A', 'B'])
# now replace the location use the index of each df selected from value by .loc function
# first select the value from df2 column A
for values in df2['A'].unique():
    # then locate the position in df1 and replace it by the VALUE of the position in df2
    df1.loc[df1[df1['A'] == (values)].index, 'B'] = df2.loc[df2[df2['A'] == (values)].index, 'B'].values

# %%
df1
