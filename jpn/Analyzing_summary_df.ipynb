# %%
# this is the code to plot out the figures for the WGS data
# by now you will need to run both YHscript_2 and YHscript_3 to perform the data analysis and construct the final dataframe
# all the plotting will be performed in the analysis folder under the BASEDIR

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import shutil
import pandas as pd
import random
import collections
import math
import sys
from pandas.tools.plotting import table
from itertools import product
from Bio import SeqIO

# %%
use argparse to do this
BASEDIR = '/home/yiheng/test/20170617_FAH05731'

# %%
# first check if the analysis folder is there
folder_list = 'analysis  basecalled_data  scripts  tracking  workspace'.split(' ')
for x in range(0,folder_list.count('')):
    folder_list.remove('')
#fix this test
if not set(os.listdir(os.path.abspath(BASEDIR))) == set (folder_list):
    print("Something wrong with basefolder. check it please.")

# %%
# get the dataframe there
dataframe = os.path.join(BASEDIR, 'analysis', 'summary_df.tab')
sum_df = pd.read_csv(dataframe, sep='\t')

# %%
sum_df.columns
# Out:
# Index(['read_id', 'passes_filtering', 'sequence_length_template',
#        'mean_qscore_template', 'barcode_arrangement', 'barcode_score', 'kit',
#        'variant', 'pc_survived', 'nl_survived', 'qseqid_rg', 'sseqid_rg',
#        'evalue_rg', 'length_rg', 'pident_rg', 'nident_rg', 'sacc_rg',
#        'staxids_rg', 'scomnames_rg', 'read_length_pc_x', 'qseqid_nt',
#        'sseqid_nt', 'evalue_nt', 'length_nt', 'pident_nt', 'nident_nt',
#        'sacc_nt', 'staxids_nt', 'scomnames_nt', 'read_length_pc_y'],
#       dtype='object')

# %%
sum_df.head()
# Out:
#                                 read_id  passes_filtering  \
# 0  62a73ee6-2c8d-43be-a446-e5207e813f81              True
# 1  72072d01-818a-4b8a-ba5d-427e15d645a2              True
# 2  ef2ca42d-1299-4fbc-b002-0db746ab387c              True
# 3  114b1d7a-7e36-4edc-91f6-3ebc4d08e5bb              True
# 4  13b76f9d-a6da-440c-a201-d9d23428c1c9              True
#
#    sequence_length_template  mean_qscore_template barcode_arrangement  \
# 0                      1405                 9.503           barcode07
# 1                      1530                 8.137        unclassified
# 2                      1825                 9.718        unclassified
# 3                      2424                 7.315        unclassified
# 4                      3215                12.354           barcode05
#
#    barcode_score  kit variant  pc_survived  nl_survived        ...         \
# 0      68.644066   BC    var1         True         True        ...
# 1      57.033333   BC    var1        False        False        ...
# 2      53.366665   BC    var2        False        False        ...
# 3      45.423729   BC    var2        False        False        ...
# 4      82.641510  LBW    var1         True         True        ...
#
#   qseqid_nt sseqid_nt  evalue_nt  length_nt  pident_nt  nident_nt sacc_nt  \
# 0       NaN       NaN        NaN        NaN        NaN        NaN     NaN
# 1       NaN       NaN        NaN        NaN        NaN        NaN     NaN
# 2       NaN       NaN        NaN        NaN        NaN        NaN     NaN
# 3       NaN       NaN        NaN        NaN        NaN        NaN     NaN
# 4       NaN       NaN        NaN        NaN        NaN        NaN     NaN
#
#    staxids_nt  scomnames_nt  read_length_pc_y
# 0         NaN           NaN               NaN
# 1         NaN           NaN               NaN
# 2         NaN           NaN               NaN
# 3         NaN           NaN               NaN
# 4         NaN           NaN               NaN
#
# [5 rows x 30 columns]

# %%
sum_df.qseqid_rg.fillna(False, inplace=True)
sum_df.qseqid_nt.fillna(False, inplace=True)

# %%
sum_df[(sum_df.qseqid_nt != False) & (sum_df.qseqid_rg == False)]
# Out:
#                                      read_id  passes_filtering  \
# 6       48eaaa70-c50a-4718-979f-56d3554be7fd              True
# 7       504997af-d2c1-48bf-a882-975607522fd2              True
# 172     955e44c2-1a1f-42a0-ba84-9da9fb1aa765              True
# 597     2c6999aa-fdfd-479d-a3af-c15850e981ae              True
# 1019    dd806f06-33b5-46e8-930d-b6f0f492ff60             False
# 1117    86eb57b5-9c49-4982-84ec-1556a4fc5d33              True
# 1171    08150526-53a3-4881-8aa2-04cd55f5b322              True
# 1193    8097386c-6e8c-4542-9b5d-987c219ba105              True
# 1272    9b2467c2-3c50-4113-be5e-e643862cd627              True
# 1535    f1a0cdf6-da8f-4347-a39c-db6516c52adf              True
# 1765    f0fdcad4-9545-4293-a643-dd06bbef93b7              True
# 1770    222be9e9-b4ad-423b-881c-67193a408563              True
# 2119    b52f652e-0dd9-4ad3-9d5a-bb07eac08beb             False
# 2196    e7e6ce59-0e73-4339-a9ef-88369c53168a              True
# 2215    c46020fa-37eb-4cb4-8e5d-5b6598d91854              True
# 2300    16f910f8-9727-4d9c-9d1d-39ed60cfa158              True
# 2599    d4d5dc7a-6e06-4029-b258-7036fdc0e0e5              True
# 2839    60edd049-ef60-428c-b765-7194b941e084              True
# 3123    488a023d-72d4-4128-b72f-e8965e31de26             False
# 3411    57af564d-3f89-4de7-8c34-acfbd0aa4e5c              True
# 3459    19b22a3d-14da-4bc8-a583-5bc0785615a0              True
# 3505    c477857f-e504-4da0-9d4b-ca2e476102e1              True
# 3514    2641ebde-849c-4333-95ae-687171c020d1              True
# 3703    9dd41d32-c88e-4dba-b2da-d65236c3e97d              True
# 3709    4f89f03f-a8ae-497e-a0d3-ac6650a1c927              True
# 3871    1cb0991a-55d8-4d29-af43-8dbc87af3ad4             False
# 3959    4be8d23a-aec9-4e35-9b57-20bc95f4539e             False
# 3975    7c315245-5ea1-46a5-bf2f-63ad48444234              True
# 4256    08474243-4857-4fa3-9d40-c6ba47a5aaaa              True
# 4388    54733761-e33b-4c06-b255-0b6a4e6feea1              True
# ...                                      ...               ...
# 236461  49054e89-4dae-4dbe-878b-f7935450594c              True
# 236493  4aa2372f-ddc9-4131-b21b-a36c2df7f49d              True
# 236580  5d9ddf01-373d-4092-b543-e4ca92badf42              True
# 237208  8466c571-1224-4cf0-b59f-ff098764b1ee              True
# 237372  a0b5c5a8-bac4-4a5c-9d1e-ebe5dd1645ea              True
# 237433  960fb34c-de29-43db-89ce-58c9d2ab20bb              True
# 237602  d3e4503c-9b96-4e3e-9378-4a6d6d42f773              True
# 237915  7ddaec94-f540-4330-9806-0a2a45b96993              True
# 238015  09c15c8b-f551-4fe0-b746-a6f9acb6d898              True
# 238290  0bc1ab9a-00e3-4cf5-9ee1-1b3e3cabcb36              True
# 238325  77b933fe-1f1a-43bb-b5ef-6319abe52e02              True
# 238442  15cf1c07-859f-4d5e-86d7-1f450f7c57c4              True
# 238656  3b736eac-fe23-471c-8f44-7cebe4ffee0f              True
# 238808  2b6a3d26-db9a-439b-bb0e-54a306bc329a              True
# 238973  953f4fd0-8020-45d9-a2e1-7af14d53a84e              True
# 239278  e1ee470d-834c-4679-a1f4-6a8f92db5a0b              True
# 239355  51b3fc40-53b8-40a3-9ee3-d3181e41c5ab              True
# 239736  f114256f-549d-4f9b-9cc3-ab28c43b2f43              True
# 239744  5d3f4b52-7a8a-4f00-8275-d4d0e8518987              True
# 239784  f6d1997b-8922-4583-b1ac-196255ce00c2              True
# 239916  7b2451d5-b746-496c-a585-35941c01ab5b              True
# 239935  6bff219a-8c72-41d9-9081-0629ce7cbe21              True
# 239959  54625f2e-a6e8-4e79-8fab-d8505958e47b              True
# 240068  076ba148-a16a-4882-99b6-061d9d7fa260              True
# 240408  b55bb06f-3faf-49c0-a1f3-27a7416d9d83              True
# 240489  b82505af-1e8c-4295-8c5b-86a6ece411e0              True
# 241229  c814487e-fcce-46c2-9786-1460a170c730              True
# 241358  36e9709e-ec2d-48a4-b7d8-6b2504c1a9f3              True
# 241705  8c937fe0-deb6-4bc4-86a8-aed10d89380b              True
# 242179  b9e08f7b-bc7e-48a3-aabd-9dab15a6f255              True
#
#         sequence_length_template  mean_qscore_template barcode_arrangement  \
# 6                           3990                12.361           barcode04
# 7                           2591                11.425           barcode06
# 172                         1793                10.298           barcode04
# 597                         5679                11.467           barcode01
# 1019                        1049                 5.990        unclassified
# 1117                        2447                11.925           barcode07
# 1171                        4957                12.473           barcode07
# 1193                        2642                10.312           barcode02
# 1272                        2429                 7.816           barcode03
# 1535                        3942                12.129           barcode04
# 1765                        5981                12.039           barcode06
# 1770                        4640                11.102           barcode04
# 2119                        6573                 6.989        unclassified
# 2196                       12022                11.738           barcode02
# 2215                        2467                12.498           barcode06
# 2300                        2183                10.084           barcode02
# 2599                        7520                12.246           barcode06
# 2839                        2107                11.758           barcode01
# 3123                         941                 4.988        unclassified
# 3411                        2922                 9.355           barcode04
# 3459                        1567                11.492           barcode01
# 3505                        2896                 9.867           barcode01
# 3514                       15204                10.362           barcode06
# 3703                        7139                10.485           barcode07
# 3709                        6610                12.057           barcode06
# 3871                         689                 4.782        unclassified
# 3959                         670                 4.706        unclassified
# 3975                        1579                11.982           barcode02
# 4256                        6018                10.378           barcode04
# 4388                        7239                12.216           barcode06
# ...                          ...                   ...                 ...
# 236461                      3125                13.057           barcode01
# 236493                      4137                13.292           barcode06
# 236580                      3749                 9.099           barcode06
# 237208                      2847                12.499           barcode02
# 237372                      5082                12.683           barcode02
# 237433                      1992                12.558           barcode07
# 237602                      1840                12.254           barcode01
# 237915                      2695                10.774           barcode06
# 238015                      2485                12.437           barcode04
# 238290                      1505                12.208           barcode02
# 238325                     12584                12.801           barcode05
# 238442                      5879                13.265           barcode06
# 238656                      4079                10.768           barcode04
# 238808                      2164                12.474           barcode06
# 238973                      3874                12.523           barcode06
# 239278                      2268                10.164           barcode02
# 239355                      5310                11.888           barcode04
# 239736                      1467                11.448           barcode06
# 239744                      2183                12.893           barcode07
# 239784                      2708                12.738           barcode07
# 239916                       526                12.473           barcode01
# 239935                      2520                11.376           barcode06
# 239959                      3305                13.095           barcode04
# 240068                      3890                12.156           barcode04
# 240408                      5107                12.475           barcode07
# 240489                      5394                12.663           barcode02
# 241229                      3118                12.421           barcode04
# 241358                      3182                12.459           barcode01
# 241705                      2946                13.432           barcode06
# 242179                      2412                13.071           barcode01
#
#         barcode_score  kit variant  pc_survived  nl_survived  \
# 6           74.847458   BC    var2         True         True
# 7           72.133331   BC    var2         True         True
# 172         68.576271   BC    var1         True         True
# 597         84.237289   BC    var1         True         True
# 1019        38.078430  RAB    var2         True         True
# 1117        66.633331   BC    var2         True         True
# 1171        83.800003   BC    var1         True         True
# 1193        64.237289   BC    var1         True         True
# 1272        86.203392   BC    var2         True         True
# 1535        86.101692   BC    var1         True         True
# 1765        91.016953   BC    var1         True         True
# 1770        80.833336   BC    var2         True         True
# 2119        40.566666   BC    var2         True         True
# 2196        99.166664   BC    var2         True         True
# 2215        85.864410   BC    var1         True         True
# 2300        73.084747   BC    var1         True         True
# 2599        74.745766   BC    var1         True         True
# 2839        81.491524   BC    var1         True         True
# 3123        30.711111   NB    var2         True         True
# 3411        72.833336   BC    var1         True         True
# 3459        85.627121   BC    var1         True         True
# 3505        68.339622  LBW    var2         True         True
# 3514        87.796608   BC    var1         True         True
# 3703        87.966103   BC    var1         True         True
# 3709        88.542374   BC    var1         True         True
# 3871        31.568628  RAB    var2         True         True
# 3959        33.333332   NB    var1         True         True
# 3975        92.847458   BC    var2         True         True
# 4256        71.932205   BC    var1         True         True
# 4388        79.830505   BC    var2         True         True
# ...               ...  ...     ...          ...          ...
# 236461      96.474579   BC    var1         True         True
# 236493      90.983047   BC    var1         True         True
# 236580      68.677963   BC    var1         True         True
# 237208      93.966103   BC    var1         True         True
# 237372      71.699997   BC    var1         True         True
# 237433      86.466667   BC    var2         True         True
# 237602      82.305084   BC    var1         True         True
# 237915      78.900002   BC    var2         True         True
# 238015      94.500000   BC    var2         True         True
# 238290      82.300003   BC    var2         True         True
# 238325      98.983047   BC    var1         True         True
# 238442      94.233330   BC    var2         True         True
# 238656      89.627121   BC    var1         True         True
# 238808      96.305084   BC    var1         True         True
# 238973      98.766670   BC    var2         True         True
# 239278      74.610168   BC    var1         True         True
# 239355      81.366669   BC    var2         True         True
# 239736      69.333336   BC    var2         True         True
# 239744      77.300003   BC    var2         True         True
# 239784      79.084747   BC    var1         True         True
# 239916      66.610168   BC    var1         True         True
# 239935      91.266670   BC    var2         True         True
# 239959      77.491524   BC    var1         True         True
# 240068      72.067795   BC    var2         True         True
# 240408      93.728813   BC    var1         True         True
# 240489      65.000000   BC    var2         True         True
# 241229      82.133331   BC    var2         True         True
# 241358      81.593224   BC    var1         True         True
# 241705      89.288139   BC    var1         True         True
# 242179      65.627121   BC    var1         True         True
#
#               ...                                    qseqid_nt  \
# 6             ...         48eaaa70-c50a-4718-979f-56d3554be7fd
# 7             ...         504997af-d2c1-48bf-a882-975607522fd2
# 172           ...         955e44c2-1a1f-42a0-ba84-9da9fb1aa765
# 597           ...         2c6999aa-fdfd-479d-a3af-c15850e981ae
# 1019          ...         dd806f06-33b5-46e8-930d-b6f0f492ff60
# 1117          ...         86eb57b5-9c49-4982-84ec-1556a4fc5d33
# 1171          ...         08150526-53a3-4881-8aa2-04cd55f5b322
# 1193          ...         8097386c-6e8c-4542-9b5d-987c219ba105
# 1272          ...         9b2467c2-3c50-4113-be5e-e643862cd627
# 1535          ...         f1a0cdf6-da8f-4347-a39c-db6516c52adf
# 1765          ...         f0fdcad4-9545-4293-a643-dd06bbef93b7
# 1770          ...         222be9e9-b4ad-423b-881c-67193a408563
# 2119          ...         b52f652e-0dd9-4ad3-9d5a-bb07eac08beb
# 2196          ...         e7e6ce59-0e73-4339-a9ef-88369c53168a
# 2215          ...         c46020fa-37eb-4cb4-8e5d-5b6598d91854
# 2300          ...         16f910f8-9727-4d9c-9d1d-39ed60cfa158
# 2599          ...         d4d5dc7a-6e06-4029-b258-7036fdc0e0e5
# 2839          ...         60edd049-ef60-428c-b765-7194b941e084
# 3123          ...         488a023d-72d4-4128-b72f-e8965e31de26
# 3411          ...         57af564d-3f89-4de7-8c34-acfbd0aa4e5c
# 3459          ...         19b22a3d-14da-4bc8-a583-5bc0785615a0
# 3505          ...         c477857f-e504-4da0-9d4b-ca2e476102e1
# 3514          ...         2641ebde-849c-4333-95ae-687171c020d1
# 3703          ...         9dd41d32-c88e-4dba-b2da-d65236c3e97d
# 3709          ...         4f89f03f-a8ae-497e-a0d3-ac6650a1c927
# 3871          ...         1cb0991a-55d8-4d29-af43-8dbc87af3ad4
# 3959          ...         4be8d23a-aec9-4e35-9b57-20bc95f4539e
# 3975          ...         7c315245-5ea1-46a5-bf2f-63ad48444234
# 4256          ...         08474243-4857-4fa3-9d40-c6ba47a5aaaa
# 4388          ...         54733761-e33b-4c06-b255-0b6a4e6feea1
# ...           ...                                          ...
# 236461        ...         49054e89-4dae-4dbe-878b-f7935450594c
# 236493        ...         4aa2372f-ddc9-4131-b21b-a36c2df7f49d
# 236580        ...         5d9ddf01-373d-4092-b543-e4ca92badf42
# 237208        ...         8466c571-1224-4cf0-b59f-ff098764b1ee
# 237372        ...         a0b5c5a8-bac4-4a5c-9d1e-ebe5dd1645ea
# 237433        ...         960fb34c-de29-43db-89ce-58c9d2ab20bb
# 237602        ...         d3e4503c-9b96-4e3e-9378-4a6d6d42f773
# 237915        ...         7ddaec94-f540-4330-9806-0a2a45b96993
# 238015        ...         09c15c8b-f551-4fe0-b746-a6f9acb6d898
# 238290        ...         0bc1ab9a-00e3-4cf5-9ee1-1b3e3cabcb36
# 238325        ...         77b933fe-1f1a-43bb-b5ef-6319abe52e02
# 238442        ...         15cf1c07-859f-4d5e-86d7-1f450f7c57c4
# 238656        ...         3b736eac-fe23-471c-8f44-7cebe4ffee0f
# 238808        ...         2b6a3d26-db9a-439b-bb0e-54a306bc329a
# 238973        ...         953f4fd0-8020-45d9-a2e1-7af14d53a84e
# 239278        ...         e1ee470d-834c-4679-a1f4-6a8f92db5a0b
# 239355        ...         51b3fc40-53b8-40a3-9ee3-d3181e41c5ab
# 239736        ...         f114256f-549d-4f9b-9cc3-ab28c43b2f43
# 239744        ...         5d3f4b52-7a8a-4f00-8275-d4d0e8518987
# 239784        ...         f6d1997b-8922-4583-b1ac-196255ce00c2
# 239916        ...         7b2451d5-b746-496c-a585-35941c01ab5b
# 239935        ...         6bff219a-8c72-41d9-9081-0629ce7cbe21
# 239959        ...         54625f2e-a6e8-4e79-8fab-d8505958e47b
# 240068        ...         076ba148-a16a-4882-99b6-061d9d7fa260
# 240408        ...         b55bb06f-3faf-49c0-a1f3-27a7416d9d83
# 240489        ...         b82505af-1e8c-4295-8c5b-86a6ece411e0
# 241229        ...         c814487e-fcce-46c2-9786-1460a170c730
# 241358        ...         36e9709e-ec2d-48a4-b7d8-6b2504c1a9f3
# 241705        ...         8c937fe0-deb6-4bc4-86a8-aed10d89380b
# 242179        ...         b9e08f7b-bc7e-48a3-aabd-9dab15a6f255
#
#                                 sseqid_nt      evalue_nt  length_nt  \
# 6             gi|445198867|gb|CP004045.1|   0.000000e+00     3959.0
# 7             gi|970580326|gb|CP013183.1|   0.000000e+00     2480.0
# 172         gi|1206257127|emb|LT855380.1|   0.000000e+00     1414.0
# 597         gi|1206257127|emb|LT855380.1|   0.000000e+00     5839.0
# 1019          gi|850474981|gb|CP011886.1|   1.000000e-03       30.0
# 1117          gi|970580326|gb|CP013183.1|   0.000000e+00     2333.0
# 1171        gi|1044865862|dbj|AP017423.1|  3.000000e-136     1522.0
# 1193          gi|445198867|gb|CP004045.1|   0.000000e+00     2550.0
# 1272         gi|157886353|emb|CU457792.5|   9.000000e-04       53.0
# 1535          gi|970580326|gb|CP013183.1|   0.000000e+00     3885.0
# 1765          gi|817568272|gb|CP006256.1|   0.000000e+00     6144.0
# 1770        gi|1206257127|emb|LT855380.1|   0.000000e+00     4645.0
# 2119         gi|685042172|emb|LN590697.1|   9.000000e-03       40.0
# 2196          gi|445198867|gb|CP004045.1|   0.000000e+00    12442.0
# 2215          gi|817568272|gb|CP006256.1|   0.000000e+00     2392.0
# 2300          gi|445198867|gb|CP004045.1|   0.000000e+00     2114.0
# 2599          gi|970580326|gb|CP013183.1|   0.000000e+00     3956.0
# 2839         gi|312173356|emb|FR719195.1|  4.000000e-171     1725.0
# 3123     gi|964160653|ref|XM_001954179.2|   1.000000e-03       33.0
# 3411          gi|817568272|gb|CP006256.1|   0.000000e+00     2277.0
# 3459         gi|299060424|emb|FP236843.1|   7.000000e-03       29.0
# 3505          gi|970580326|gb|CP013183.1|   0.000000e+00     2814.0
# 3514          gi|817568272|gb|CP006256.1|   0.000000e+00    15666.0
# 3703          gi|695169020|gb|CP009571.1|  8.000000e-138     1348.0
# 3709        gi|1206257127|emb|LT855380.1|   0.000000e+00     5706.0
# 3871          gi|667678325|gb|CP008953.1|   3.000000e-03       29.0
# 3959    gi|1158927108|ref|XM_020455921.1|   1.000000e-03       40.0
# 3975         gi|1008893959|gb|CP014771.1|   3.000000e-51      402.0
# 4256        gi|1085920192|emb|LT629769.1|   0.000000e+00     6248.0
# 4388          gi|817568272|gb|CP006256.1|   0.000000e+00     7383.0
# ...                                   ...            ...        ...
# 236461       gi|312173689|emb|FR719196.1|   0.000000e+00     2410.0
# 236493        gi|817568272|gb|CP006256.1|   0.000000e+00     4185.0
# 236580      gi|1041605363|emb|LT222319.1|   0.000000e+00     3942.0
# 237208  gi|1070545883|ref|XM_018534136.1|  9.000000e-139      708.0
# 237372        gi|283814236|gb|CP001769.1|   7.000000e-03       30.0
# 237433        gi|445198867|gb|CP004045.1|   0.000000e+00     1911.0
# 237602  gi|1069896037|ref|XM_018404057.1|   1.000000e-10       66.0
# 237915      gi|1085717528|emb|LT629706.1|   0.000000e+00     2698.0
# 238015        gi|817568272|gb|CP006256.1|   0.000000e+00     2420.0
# 238290  gi|1070552097|ref|XM_018525127.1|   0.000000e+00     1290.0
# 238325   gi|302408408|ref|XM_003001993.1|   4.000000e-24      199.0
# 238442       gi|224962304|emb|FP236842.1|   0.000000e+00     4264.0
# 238656        gi|970580326|gb|CP013183.1|   0.000000e+00     4299.0
# 238808       gi|1167016347|gb|CP020351.1|   1.000000e-36      319.0
# 238973        gi|523811606|gb|CP006053.1|  3.000000e-129      702.0
# 239278      gi|1206257127|emb|LT855380.1|   0.000000e+00     2240.0
# 239355       gi|1057481511|gb|CP016889.1|   0.000000e+00     5451.0
# 239736   gi|698993465|ref|XM_009855412.1|   2.000000e-03       30.0
# 239744  gi|1148905068|ref|XM_020272029.1|   7.000000e-44      253.0
# 239784        gi|695169020|gb|CP009571.1|   0.000000e+00     2687.0
# 239916        gi|817568272|gb|CP006256.1|  4.000000e-139      424.0
# 239935  gi|1069470654|ref|XM_018274300.1|   2.000000e-06       45.0
# 239959   gi|258572801|ref|XM_002545117.1|   4.000000e-08       61.0
# 240068  gi|1147207346|ref|XM_020198795.1|   3.000000e-10       55.0
# 240408       gi|1130060874|gb|CP019038.1|  1.000000e-109     1020.0
# 240489      gi|1003333673|emb|LK056666.1|   0.000000e+00     1600.0
# 241229  gi|1101792078|ref|XM_019139015.1|   3.000000e-24      239.0
# 241358       gi|188027207|emb|CU468135.1|   0.000000e+00     2410.0
# 241705       gi|702073471|emb|FO905845.1|   8.000000e-70      346.0
# 242179        gi|970580326|gb|CP013183.1|   0.000000e+00     2316.0
#
#         pident_nt  nident_nt       sacc_nt  staxids_nt  \
# 6           89.39     3539.0      CP004045   1282356.0
# 7           86.25     2139.0      CP013183    199201.0
# 172         84.58     1196.0      LT855380     33069.0
# 597         81.25     4744.0      LT855380     33069.0
# 1019       100.00       30.0      CP011886    112262.0
# 1117        89.50     2088.0      CP013183    199201.0
# 1171        73.92     1125.0      AP017423    143813.0
# 1193        82.04     2092.0      CP004045   1282356.0
# 1272        86.79       46.0      CU457792      7955.0
# 1535        88.21     3427.0      CP013183    199201.0
# 1765        88.09     5412.0      CP006256   1324932.0
# 1770        82.99     3855.0      LT855380     33069.0
# 2119        92.50       37.0      LN590697      7962.0
# 2196        87.87    10933.0      CP004045   1282356.0
# 2215        87.63     2096.0      CP006256   1324932.0
# 2300        83.35     1762.0      CP004045   1282356.0
# 2599        88.35     3495.0      CP013183    199201.0
# 2839        74.43     1284.0      FR719195    889211.0
# 3123        96.97       32.0  XM_001954179      7217.0
# 3411        78.48     1787.0      CP006256   1324932.0
# 3459       100.00       29.0      FP236843    634500.0
# 3505        83.58     2352.0      CP013183    199201.0
# 3514        84.84    13291.0      CP006256   1324932.0
# 3703        75.15     1013.0      CP009571   1549858.0
# 3709        86.30     4924.0      LT855380     33069.0
# 3871       100.00       29.0      CP008953    208439.0
# 3959        92.50       37.0  XM_020455921      8019.0
# 3975        77.36      311.0      CP014771   1484116.0
# 4256        79.91     4993.0      LT629769       317.0
# 4388        86.67     6399.0      CP006256   1324932.0
# ...           ...        ...           ...         ...
# 236461      78.92     1902.0      FR719196    889211.0
# 236493      91.49     3829.0      CP006256   1324932.0
# 236580      76.15     3002.0      LT222319   1583341.0
# 237208      80.37      569.0  XM_018534136      5599.0
# 237372     100.00       30.0      CP001769    504472.0
# 237433      89.17     1704.0      CP004045   1282356.0
# 237602      89.39       59.0  XM_018404057   1296121.0
# 237915      82.13     2216.0      LT629706    200451.0
# 238015      88.84     2150.0      CP006256   1324932.0
# 238290      78.99     1019.0  XM_018525127      5599.0
# 238325      78.89      157.0  XM_003001993    526221.0
# 238442      78.03     3327.0      FP236842    634499.0
# 238656      81.32     3496.0      CP013183    199201.0
# 238808      77.43      247.0      CP020351     53707.0
# 238973      80.63      566.0      CP006053   1173427.0
# 239278      78.71     1763.0      LT855380     33069.0
# 239355      85.89     4682.0      CP016889       549.0
# 239736     100.00       30.0  XM_009855412    510951.0
# 239744      81.42      206.0  XM_020272029    236234.0
# 239784      77.93     2094.0      CP009571   1549858.0
# 239916      89.39      379.0      CP006256   1324932.0
# 239935      93.33       42.0  XM_018274300    342668.0
# 239959      88.52       54.0  XM_002545117    336963.0
# 240068      92.73       51.0  XM_020198795    690307.0
# 240408      75.29      768.0      CP019038   1141883.0
# 240489      77.06     1233.0      LK056666     49012.0
# 241229      77.41      185.0  XM_019139015   1295533.0
# 241358      78.67     1896.0      CU468135    465817.0
# 241705      81.79      283.0      FO905845    225344.0
# 242179      91.75     2125.0      CP013183    199201.0
#
#                                              scomnames_nt  read_length_pc_y
# 6                              Pseudomonas poae RE*1-1-14            3826.0
# 7                          Pseudomonas syringae pv. lapsa            2379.0
# 172                               Pseudomonas viridiflava            1615.0
# 597                               Pseudomonas viridiflava            5473.0
# 1019                           Ovis canadensis canadensis            1042.0
# 1117                       Pseudomonas syringae pv. lapsa            2260.0
# 1171                               Pseudomonas sp. LAB-08            4744.0
# 1193                           Pseudomonas poae RE*1-1-14            2457.0
# 1272                                          Danio rerio            2252.0
# 1535                       Pseudomonas syringae pv. lapsa            3746.0
# 1765              Pseudomonas syringae pv. syringae HS191            5892.0
# 1770                              Pseudomonas viridiflava            4443.0
# 2119                                      Cyprinus carpio            6473.0
# 2196                           Pseudomonas poae RE*1-1-14           11816.0
# 2215              Pseudomonas syringae pv. syringae HS191            2267.0
# 2300                           Pseudomonas poae RE*1-1-14            1991.0
# 2599                       Pseudomonas syringae pv. lapsa            7313.0
# 2839                      Erwinia amylovora ATCC BAA-2158            1891.0
# 3123                                 Drosophila ananassae             933.0
# 3411              Pseudomonas syringae pv. syringae HS191            2784.0
# 3459                             Erwinia billingiae Eb661            1386.0
# 3505                       Pseudomonas syringae pv. lapsa            2701.0
# 3514              Pseudomonas syringae pv. syringae HS191           14938.0
# 3703                                    Sphingomonas taxi            7034.0
# 3709                              Pseudomonas viridiflava            6491.0
# 3871                               Amycolatopsis japonica             680.0
# 3959                                 Oncorhynchus kisutch             670.0
# 3975                           Hymenobacter sp. PAMC26554            1365.0
# 4256                                 Pseudomonas syringae            5816.0
# 4388              Pseudomonas syringae pv. syringae HS191            7020.0
# ...                                                   ...               ...
# 236461                    Erwinia amylovora ATCC BAA-2158            2937.0
# 236493            Pseudomonas syringae pv. syringae HS191            4030.0
# 236580                                 Pseudomonas sp. 58            3643.0
# 237208                               Alternaria alternata            2655.0
# 237372                          Spirosoma linguale DSM 74            4883.0
# 237433                         Pseudomonas poae RE*1-1-14            1812.0
# 237602                 Cryptococcus dejecticola CBS 10117            1733.0
# 237915                                   Pseudomonas poae            2495.0
# 238015            Pseudomonas syringae pv. syringae HS191            2322.0
# 238290                               Alternaria alternata            1317.0
# 238325                     Verticillium alfalfae VaMs.102           12395.0
# 238442                          Erwinia pyrifoliae Ep1/96            5690.0
# 238656                     Pseudomonas syringae pv. lapsa            3907.0
# 238808                Pseudomonas syringae pv. lachrymans            1975.0
# 238973  Salmonella enterica subsp. enterica serovar Ba...            3693.0
# 239278                            Pseudomonas viridiflava            2153.0
# 239355                                Pantoea agglomerans            5191.0
# 239736                   Neurospora tetrasperma FGSC 2508            1305.0
# 239744                                 Diplodia corticola            1977.0
# 239784                                  Sphingomonas taxi            2551.0
# 239916            Pseudomonas syringae pv. syringae HS191             397.0
# 239935                        Pseudogymnoascus verrucosus            2327.0
# 239959                           Uncinocarpus reesii 1704            3117.0
# 240068                   Aspergillus aculeatus ATCC 16872            3711.0
# 240408                                 Massilia sp. 6NM-7            4984.0
# 240489                            Sporisorium scitamineum            5206.0
# 241229                  Cryptococcus amylolentus CBS 6039            2951.0
# 241358                        Erwinia tasmaniensis Et1/99            2998.0
# 241705           Leptosphaeria biglobosa 'thlaspii' group            2737.0
# 242179                     Pseudomonas syringae pv. lapsa            2245.0
#
# [1550 rows x 30 columns]

# %%
(sum_df[(sum_df.qseqid_nt == False) & (sum_df.qseqid_rg == False)])
# Out:
# 84864

# %%
len(sum_df)
# Out:
# 242769

# %%
[sum_df.qseqid_nt == False]
# Out:
# [0          True
#  1          True
#  2          True
#  3          True
#  4          True
#  5          True
#  6         False
#  7         False
#  8          True
#  9          True
#  10         True
#  11         True
#  12         True
#  13         True
#  14         True
#  15         True
#  16         True
#  17         True
#  18         True
#  19         True
#  20         True
#  21         True
#  22         True
#  23         True
#  24         True
#  25         True
#  26         True
#  27         True
#  28         True
#  29         True
#            ...
#  242739     True
#  242740     True
#  242741     True
#  242742     True
#  242743     True
#  242744     True
#  242745     True
#  242746     True
#  242747     True
#  242748     True
#  242749     True
#  242750     True
#  242751     True
#  242752     True
#  242753     True
#  242754     True
#  242755     True
#  242756     True
#  242757     True
#  242758     True
#  242759     True
#  242760     True
#  242761     True
#  242762     True
#  242763     True
#  242764     True
#  242765     True
#  242766     True
#  242767     True
#  242768     True
#  Name: qseqid_nt, Length: 242769, dtype: bool]

# %%
t
