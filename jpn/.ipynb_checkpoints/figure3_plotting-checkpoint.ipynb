# %% [markdown]
# This is a notebook that use the FLOCELLID_taxa.tab file in the WGS folder to generate ncbi hit plot for the four flowcells.

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
BASEDIR = '/home/yiheng/analysis/WGS'

# %%
# get the summary dataframe
FC1_taxa = os.path.join(BASEDIR, 'run1_taxa.tab')
FC2_taxa = os.path.join(BASEDIR, 'run2_taxa.tab')
#FC3_taxa = os.path.join(BASEDIR, 'FAH05432_taxa.tab')
FC4_taxa = os.path.join(BASEDIR, 'FAH05731_taxa.tab')

FC1_taxa_df = pd.read_csv(FC1_taxa, sep = '\t')
FC2_taxa_df = pd.read_csv(FC2_taxa, sep = '\t')
#FC3_taxa_df = pd.read_csv(FC3_taxa, sep = '\t')
FC4_taxa_df = pd.read_csv(FC4_taxa, sep = '\t')

# %%
joint_taxa_df = pd.concat([FC1_taxa_df,  
                           FC2_taxa_df, 
                           FC4_taxa_df], ignore_index=True)

# %%
joint_taxa_df
# Out:
#                                    read_id barcode_arrangement  nident_nt  \
# 0     03fe0b0a-1fb6-4102-909b-443d842f1fc9           barcode01     1053.0
# 1     ea8614ad-f6b7-4cf8-a584-4b784b761dd2           barcode01      636.0
# 2     74bf46de-9d7f-4d5e-8422-4395d4d36572           barcode01      222.0
# 3     e98f757d-647b-4dfd-91d7-694c7b0ab12a           barcode01      536.0
# 4     2149e363-9367-4d32-b3af-996b77a5e99a           barcode01      601.0
# 5     40eae7a5-f0b0-4a73-bc4f-3f191a2110b1           barcode01       38.0
# 6     7cf0383a-5007-4dbe-8f31-0c8b649a65f0           barcode01      601.0
# 7     1f4b2d5d-cc37-4418-a8cc-20ee0b1bff2d           barcode01      532.0
# 8     9ae4bf5f-b5c0-4369-aaa4-4e77bb44bd33           barcode01       28.0
# 9     873f3993-5807-460c-85b0-986a24f57f5b           barcode01      412.0
# 10    2c7e8ce6-83c9-457d-8925-432a5a959a36           barcode01     1669.0
# 11    1696cb40-6a9f-43f8-9945-4bdf579840f9           barcode01      323.0
# 12    3fb5c5a8-991d-4817-a8c4-381806073ff8           barcode01      315.0
# 13    fd8f8c42-a7cf-46ea-85aa-66629ece4fc1           barcode01      185.0
# 14    184b6792-0fd8-42cd-9517-744c1034ef62           barcode01      106.0
# 15    eace1fe5-29bc-44ec-8200-6f6fafbbc655           barcode01       29.0
# 16    d651b4e3-524a-4975-baa9-f7c45ee49c59           barcode01      294.0
# 17    55a3c393-8bb7-4fed-87c3-4311fd4e846f           barcode01     1136.0
# 18    dd46fb3a-b2e6-4d9a-814e-483eaa36b559           barcode01      762.0
# 19    17ddc048-1d8b-4b92-9ea2-2f479c7fbbc2           barcode01      317.0
# 20    920c085a-d19e-4f7d-96ef-325baea25b84           barcode01      405.0
# 21    77f3ba7c-cd47-40f4-8233-f3d5c8fee180           barcode01       29.0
# 22    885c2358-1071-428b-9383-a98a1d764306           barcode01      772.0
# 23    d45b3206-911b-41df-9456-41594ad980fb           barcode01     1037.0
# 24    fb00379a-8abf-46b5-9b1b-5db8ab49e838           barcode01      902.0
# 25    e95bce15-bf70-4c3b-a585-57a7c59b958a           barcode01      326.0
# 26    bed200e3-88fe-4f66-a0e0-ea873007ff38           barcode01       29.0
# 6       1276538.0     Eukaryota       Ascomycota        Dothideomycetes
# 7         1047171     Eukaryota       Ascomycota        Dothideomycetes
# 8       1660073.0      Bacteria   Proteobacteria  Epsilonproteobacteria
# 9        236234.0     Eukaryota       Ascomycota        Dothideomycetes
# 10          562.0      Bacteria   Proteobacteria    Gammaproteobacteria
# 11        49657.0     Eukaryota     Streptophyta             Liliopsida
# 12       225343.0     Eukaryota       Ascomycota        Dothideomycetes
# 13       168172.0     Eukaryota    Basidiomycota        Pucciniomycetes
# 14       716540.0      Bacteria   Proteobacteria    Gammaproteobacteria
# 15          30608     Eukaryota         Chordata               Mammalia
# 16        1276538     Eukaryota       Ascomycota        Dothideomycetes
# 17        1276538     Eukaryota       Ascomycota        Dothideomycetes
# 18       112509.0     Eukaryota     Streptophyta             Liliopsida
# 19      1276529.0     Eukaryota       Ascomycota        Dothideomycetes
# 20      1276529.0     Eukaryota       Ascomycota        Dothideomycetes
# 21         7463.0     Eukaryota       Arthropoda                Insecta
# 22      1276529.0     Eukaryota       Ascomycota        Dothideomycetes
# 23      1276529.0     Eukaryota       Ascomycota        Dothideomycetes
# 24       199201.0      Bacteria   Proteobacteria    Gammaproteobacteria
# 25         4565.0     Eukaryota     Streptophyta             Liliopsida
# 26       174628.0     Eukaryota       Arthropoda                Insecta
# 27         5599.0     Eukaryota       Ascomycota        Dothideomycetes
# 28         199201      Bacteria   Proteobacteria    Gammaproteobacteria
# 29         199201      Bacteria   Proteobacteria    Gammaproteobacteria
# ...           ...           ...              ...                    ...
# 6515          549      Bacteria   Proteobacteria    Gammaproteobacteria
# 6516       336963     Eukaryota       Ascomycota         Eurotiomycetes
# 6517       690307     Eukaryota       Ascomycota         Eurotiomycetes
# 6518  1.29553e+06     Eukaryota    Basidiomycota        Tremellomycetes
# 6519         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6520       225343     Eukaryota       Ascomycota        Dothideomycetes
# 6521       223283      Bacteria   Proteobacteria    Gammaproteobacteria
# 6522         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6523       578455     Eukaryota       Ascomycota        Sordariomycetes
# 6524        43300  Unclassified     Unclassified           Unclassified
# 6525         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6526       665912     Eukaryota       Ascomycota        Dothideomycetes
# 6527       985895     Eukaryota       Ascomycota        Dothideomycetes
# 6528       861557     Eukaryota       Ascomycota        Dothideomycetes
# 6529        37762      Bacteria   Proteobacteria    Gammaproteobacteria
# 6530  1.46066e+06     Eukaryota       Ascomycota        Dothideomycetes
# 6531         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6532         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6533       671987     Eukaryota       Ascomycota        Dothideomycetes
# 6534         5221     Eukaryota    Basidiomycota        Tremellomycetes
# 6535        33069      Bacteria   Proteobacteria    Gammaproteobacteria
# 6536         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6537         5599     Eukaryota       Ascomycota        Dothideomycetes
# 6538         4565     Eukaryota     Streptophyta             Liliopsida
# 6539        15368     Eukaryota     Streptophyta             Liliopsida
# 6540  1.20253e+06     Eukaryota       Ascomycota        Sordariomycetes
# 6541       671987     Eukaryota       Ascomycota        Dothideomycetes
# 6537       Pleosporales         Pleosporaceae         Alternaria
# 6538             Poales               Poaceae           Triticum
# 6539             Poales               Poaceae       Brachypodium
# 6540      Glomerellales  Plectosphaerellaceae       Verticillium
# 6541       Pleosporales         Pleosporaceae       Setosphaeria
# 6542       Pleosporales         Pleosporaceae         Alternaria
# 6543       Pleosporales         Pleosporaceae         Alternaria
# 6544      Glomerellales  Plectosphaerellaceae       Verticillium
#
#                                      species  Flowcell
# 0                Cloning vector lambda TXF97      run1
# 1                    Pseudomonas viridiflava      run1
# 2                       Zymoseptoria tritici      run1
# 3                       Zymoseptoria tritici      run1
# 4                          Triticum aestivum      run1
# 5                           Hymenolepis nana      run1
# 6                       Zymoseptoria tritici      run1
# 7                       Zymoseptoria tritici      run1
# 8                   Campylobacter sp. RM6137      run1
# 9                         Diplodia corticola      run1
# 10                          Escherichia coli      run1
# 11                              Smilax china      run1
# 12                    Leptosphaeria maculans      run1
# 13                      Puccinia striiformis      run1
# 14                         Erwinia amylovora      run1
# 15                        Microcebus murinus      run1
# 16                      Zymoseptoria tritici      run1
# 17                      Zymoseptoria tritici      run1
# 18                           Hordeum vulgare      run1
# 19                      Zymoseptoria tritici      run1
# 20                      Zymoseptoria tritici      run1
# 21                               Apis florea      run1
# 22                      Zymoseptoria tritici      run1
# 23                      Zymoseptoria tritici      run1
# 24                      Pseudomonas syringae      run1
# 25                         Triticum aestivum      run1
# 26                      Bactrocera latifrons      run1
# 27                      Alternaria alternata      run1
# 28                      Pseudomonas syringae      run1
# 29                      Pseudomonas syringae      run1
# ...                                      ...       ...
# 6515                     Pantoea agglomerans  FAH05731
# 6516                     Uncinocarpus reesii  FAH05731
# 6517                   Aspergillus aculeatus  FAH05731
# 6518                Cryptococcus amylolentus  FAH05731
# 6519                    Alternaria alternata  FAH05731
# 6520                  Leptosphaeria maculans  FAH05731
# 6521  Pseudomonas syringae group genomosp. 3  FAH05731
# 6522                    Alternaria alternata  FAH05731
# 6523                    Thielavia terrestris  FAH05731
# 6524             Cloning vector lambda TXF97  FAH05731
# 6525                    Alternaria alternata  FAH05731
# 6526                   Bipolaris sorokiniana  FAH05731
# 6527                  Leptosphaeria maculans  FAH05731
# 6528                       Pyrenophora teres  FAH05731
# 6529                        Escherichia coli  FAH05731
# 6530             Paraphaeosphaeria sporulosa  FAH05731
# 6531                    Alternaria alternata  FAH05731
# 6532                    Alternaria alternata  FAH05731
# 6533                    Setosphaeria turcica  FAH05731
# 6534            Trimorphomyces papilionaceus  FAH05731
# 6535                 Pseudomonas viridiflava  FAH05731
# 6536                    Alternaria alternata  FAH05731
# 6537                    Alternaria alternata  FAH05731
# 6538                       Triticum aestivum  FAH05731
# 6539                 Brachypodium distachyon  FAH05731
# 6540                    Verticillium dahliae  FAH05731
# 6541                    Setosphaeria turcica  FAH05731
# 6542                    Alternaria alternata  FAH05731
# 6543                    Alternaria alternata  FAH05731
# 6544                   Verticillium alfalfae  FAH05731
#
# [6545 rows x 12 columns]

# %%
#Defines a function to make manual adjustments to the NCBI taxonomic sorting
def manually_adjust_ncbi_taxonomy(rank_select, entry_select, ranks_to_edit, new_entry):
    """Select dataframe entries to edit by a specific rank (rank_select) 
    and entry related to that rank (entry_select), 
    provide a list of ranks to edit for those selected entries (ranks_to_edit),
    replace these ranks with a new entry (new_entry)"""
    if entry_select in list(joint_taxa_df[rank_select].unique()):
        selection = (joint_taxa_df[rank_select] == entry_select)
        selected_tax_ranks = ranks_to_edit
        for ranks in selected_tax_ranks:
            joint_taxa_df[ranks][selection] = new_entry

# %%
manually_adjust_ncbi_taxonomy('species', 
                            'Cloning vector lambda TXF97', 
                            ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus'], 
                            'Cloning vector lambda TXF97')

manually_adjust_ncbi_taxonomy('superkingdom', 
                            'Viruses', 
                            ['phylum', 'class'], 
                            'dsDNA viruses, no RNA stage')
# Out:
# /home/yiheng/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
#count pivot table of dataframe with taxonomic columns: 
#rows - rank names, columns - barcode, sorted by desired class
def generate_ncbi_taxonomy_pivot(tax_df, rank, bcs, num):
    """From tax_df, generate a pivot table listing num rank counts, sorted by bcs"""
    pivot_table = tax_df.pivot_table(values='nident', 
                                            index=rank, 
                                            columns='barcode', 
                                            aggfunc='count', 
                                            fill_value=0, 
                                            margins=True)
    pivot_table.columns.name = None
    return pivot_table.sort_values(bcs, axis=0, ascending=False).head(n=num)

# %%
generate_ncbi_taxonomy_pivot(joint_taxa_df, 'species','barcode05',20)
# Out:
# ------------------------------------------------------------------
# KeyError                         Traceback (most recent call last)
# <ipython-input-22-f7c1f83e36d2> in <module>()
# ----> 1 generate_ncbi_taxonomy_pivot(joint_taxa_df, 'species','barcode05',20)
#
# <ipython-input-21-d0d1413125cc> in generate_ncbi_taxonomy_pivot(tax_df, rank, bcs, num)
#       8                                             aggfunc='count',
#       9                                             fill_value=0,
# ---> 10                                             margins=True)
#      11     pivot_table.columns.name = None
#      12     return pivot_table.sort_values(bcs, axis=0, ascending=False).head(n=num)
#
# /home/yiheng/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     110         for i in values:
#     111             if i not in data:
# --> 112                 raise KeyError(i)
#     113
#     114         to_filter = []
#
# KeyError: 'nident'

# %%
#count pivot table of dataframe with taxonomic columns, includes reference genomes set across all ranks: 
#rows - rank names, columns - barcode, sorted by desired class
def generate_all_hits_pivot(rank, bcs, num, dropmaxspecies=False):
    """generate a pivot table listing num rank counts, sorted ascending by bcs"""
    blast_and_NCBI_df_list = [generate_ncbi_taxonomy_pivot(joint_taxa_df, rank, bcs, len(joint_taxa_df)), 
                    rgblast_df_joint_pivot.transpose()]
    blast_and_NCBI_hits = pd.concat(blast_and_NCBI_df_list)
    blast_and_NCBI_hits_sum = blast_and_NCBI_hits.groupby(blast_and_NCBI_hits.index).sum()
    
    max_genome = str(rgblast_df_joint_pivot_noall.ix['All'].idxmax(axis=1))
    
    if dropmaxspecies == True:
        blast_and_NCBI_hits_sum.loc['All'] = blast_and_NCBI_hits_sum.loc['All'] - blast_and_NCBI_hits_sum.loc[max_genome]
        blast_and_NCBI_hits_sum.drop(max_genome, axis=0, inplace=True)
    
    return blast_and_NCBI_hits_sum.sort_values(bcs, axis=0, ascending=False).head(n=num)
