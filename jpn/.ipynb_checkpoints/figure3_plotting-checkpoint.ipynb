# %% [markdown]
# This is a notebook that use the FLOCELLID_taxa.tab file in the WGS folder to generate ncbi hit plot for the four flowcells.

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from itertools import product

# %%
BASEDIR = '/home/yiheng/analysis/WGS'

# %%
# get the summary dataframe
FC1_taxa = os.path.join(BASEDIR, 'run1_taxa.tab')
FC2_taxa = os.path.join(BASEDIR, 'run2_taxa.tab')
FC3_taxa = os.path.join(BASEDIR, 'FAH05432_taxa.tab')
FC4_taxa = os.path.join(BASEDIR, 'FAH05731_taxa.tab')

FC1_taxa_df = pd.read_csv(FC1_taxa, sep = '\t')
FC2_taxa_df = pd.read_csv(FC2_taxa, sep = '\t')
FC3_taxa_df = pd.read_csv(FC3_taxa, sep = '\t')
FC4_taxa_df = pd.read_csv(FC4_taxa, sep = '\t')

# %%
joint_taxa_df = pd.concat([FC1_taxa_df,  
                           FC2_taxa_df,
                           FC3_taxa_df,
                           FC4_taxa_df], ignore_index=True)

# %%
joint_taxa_df
# Out:
#                                     read_id barcode_arrangement   staxids_nt  \
# 0      03fe0b0a-1fb6-4102-909b-443d842f1fc9           barcode01        43300
# 1      ea8614ad-f6b7-4cf8-a584-4b784b761dd2           barcode01        33069
# 2      74bf46de-9d7f-4d5e-8422-4395d4d36572           barcode01      1276538
# 3      e98f757d-647b-4dfd-91d7-694c7b0ab12a           barcode01      1047171
# 4      2149e363-9367-4d32-b3af-996b77a5e99a           barcode01         4565
# 5      40eae7a5-f0b0-4a73-bc4f-3f191a2110b1           barcode01       102285
# 6      7cf0383a-5007-4dbe-8f31-0c8b649a65f0           barcode01    1276538.0
# 7      1f4b2d5d-cc37-4418-a8cc-20ee0b1bff2d           barcode01      1047171
# 8      9ae4bf5f-b5c0-4369-aaa4-4e77bb44bd33           barcode01    1660073.0
# 9      873f3993-5807-460c-85b0-986a24f57f5b           barcode01     236234.0
# 10     2c7e8ce6-83c9-457d-8925-432a5a959a36           barcode01        562.0
# 11     1696cb40-6a9f-43f8-9945-4bdf579840f9           barcode01      49657.0
# 12     3fb5c5a8-991d-4817-a8c4-381806073ff8           barcode01     225343.0
# 13     fd8f8c42-a7cf-46ea-85aa-66629ece4fc1           barcode01     168172.0
# 14     184b6792-0fd8-42cd-9517-744c1034ef62           barcode01     716540.0
# 15     eace1fe5-29bc-44ec-8200-6f6fafbbc655           barcode01        30608
# 16     d651b4e3-524a-4975-baa9-f7c45ee49c59           barcode01      1276538
# 17     55a3c393-8bb7-4fed-87c3-4311fd4e846f           barcode01      1276538
# 18     dd46fb3a-b2e6-4d9a-814e-483eaa36b559           barcode01     112509.0
# 19     17ddc048-1d8b-4b92-9ea2-2f479c7fbbc2           barcode01    1276529.0
# 20     920c085a-d19e-4f7d-96ef-325baea25b84           barcode01    1276529.0
# 21     77f3ba7c-cd47-40f4-8233-f3d5c8fee180           barcode01       7463.0
# 22     885c2358-1071-428b-9383-a98a1d764306           barcode01    1276529.0
# 23     d45b3206-911b-41df-9456-41594ad980fb           barcode01    1276529.0
# 24     fb00379a-8abf-46b5-9b1b-5db8ab49e838           barcode01     199201.0
# 25     e95bce15-bf70-4c3b-a585-57a7c59b958a           barcode01       4565.0
# 26     bed200e3-88fe-4f66-a0e0-ea873007ff38           barcode01     174628.0
# 27     d5637581-f9e8-49c3-b5ea-297c6cff9b4a           barcode01       5599.0
# 28     d651c556-b9e7-4034-8353-bafd314735db           barcode02       199201
# 29     4a2ff4a6-524e-49c2-a4fe-3ab2f6e3606a           barcode02       199201
# ...                                     ...                 ...          ...
# 12368  51b3fc40-53b8-40a3-9ee3-d3181e41c5ab           barcode04          549
# 12369  54625f2e-a6e8-4e79-8fab-d8505958e47b           barcode04       336963
# 12370  076ba148-a16a-4882-99b6-061d9d7fa260           barcode04       690307
# 12371  c814487e-fcce-46c2-9786-1460a170c730           barcode04  1.29553e+06
# 12372  65500185-72a1-4432-8ef6-477b8d1aff22           barcode05         5599
# 12373  1f84b508-acd3-4be3-9ebd-8340b41412d1           barcode05       225343
# 12374  700dd3fe-9baf-40ea-846f-cc568345f8a6           barcode05       223283
# 12375  6d4580e9-d602-46cc-989b-19ca4b733ea5           barcode05         5599
# 12376  7aab488c-287f-4d0a-b11a-f159e6bdc00a           barcode05       578455
# 12377  1643b8a0-b4f6-4a29-8e3c-4bf5f464dd57           barcode05        43300
# 12378  16a1b757-7683-4690-8aa0-17a9671ce2d6           barcode05         5599
# 12379  47ad481d-f052-4c65-9a87-73b72e05b0f0           barcode05       665912
# 12380  e82f247b-ff7e-42c7-b356-cf7f865d4e6c           barcode05       985895
# 12381  b7e2e8cc-e823-4d60-9f52-74eb2bd950eb           barcode05       861557
# 12382  5369aff9-e594-4217-8c5a-bb989c77c036           barcode05        37762
# 12383  c86df1e5-7df1-4b18-82f1-f45c50e6631c           barcode05  1.46066e+06
# 12384  49e23cf1-6bb5-47b1-b9a3-e6e70cbf1f03           barcode05         5599
# 12385  84fbee48-1488-4dae-9796-7f110aebc86a           barcode05         5599
# 12386  6fc21175-d73d-4a8f-ae22-0c31cdf087dd           barcode05       671987
# 12387  4df0536b-7ccc-4cf7-a7f0-91194376b0ba           barcode05         5221
# 12388  43e3cb19-077d-4b96-806c-70446f119de6           barcode05        33069
# 12389  d1b80ccf-48d6-40f2-80c7-5b17e0f9b638           barcode05         5599
# 12390  49038563-1c61-4ec8-9852-1730544ae7c0           barcode05         5599
# 12391  3b813604-f349-46b1-82a6-2d8ba94051df           barcode05         4565
# 12392  5a9d4010-e51a-4db2-a403-ddfa2e64e417           barcode05        15368
# 12393  41184a4c-43a6-406a-80e9-212e031a80a1           barcode05  1.20253e+06
# 12394  4e0d8895-109f-4b5d-8c94-4c6110425366           barcode05       671987
# 12395  a85bf229-8a30-45a6-9114-60f93bd5ecce           barcode05         5599
# 12396  c190fdc9-e009-466a-813c-aebe6e063e94           barcode05         5599
# 12397  77b933fe-1f1a-43bb-b5ef-6319abe52e02           barcode05       526221
#
#        superkingdom           phylum                  class  \
# 0      Unclassified     Unclassified           Unclassified
# 1          Bacteria   Proteobacteria    Gammaproteobacteria
# 2         Eukaryota       Ascomycota        Dothideomycetes
# 3         Eukaryota       Ascomycota        Dothideomycetes
# 4         Eukaryota     Streptophyta             Liliopsida
# 5         Eukaryota  Platyhelminthes                Cestoda
# 6         Eukaryota       Ascomycota        Dothideomycetes
# 7         Eukaryota       Ascomycota        Dothideomycetes
# 8          Bacteria   Proteobacteria  Epsilonproteobacteria
# 9         Eukaryota       Ascomycota        Dothideomycetes
# 10         Bacteria   Proteobacteria    Gammaproteobacteria
# 11        Eukaryota     Streptophyta             Liliopsida
# 12        Eukaryota       Ascomycota        Dothideomycetes
# 13        Eukaryota    Basidiomycota        Pucciniomycetes
# 14         Bacteria   Proteobacteria    Gammaproteobacteria
# 15        Eukaryota         Chordata               Mammalia
# 16        Eukaryota       Ascomycota        Dothideomycetes
# 17        Eukaryota       Ascomycota        Dothideomycetes
# 18        Eukaryota     Streptophyta             Liliopsida
# 19        Eukaryota       Ascomycota        Dothideomycetes
# 20        Eukaryota       Ascomycota        Dothideomycetes
# 21        Eukaryota       Arthropoda                Insecta
# 22        Eukaryota       Ascomycota        Dothideomycetes
# 23        Eukaryota       Ascomycota        Dothideomycetes
# 24         Bacteria   Proteobacteria    Gammaproteobacteria
# 25        Eukaryota     Streptophyta             Liliopsida
# 26        Eukaryota       Arthropoda                Insecta
# 27        Eukaryota       Ascomycota        Dothideomycetes
# 28         Bacteria   Proteobacteria    Gammaproteobacteria
# 29         Bacteria   Proteobacteria    Gammaproteobacteria
# ...             ...              ...                    ...
# 12368      Bacteria   Proteobacteria    Gammaproteobacteria
# 12369     Eukaryota       Ascomycota         Eurotiomycetes
# 12370     Eukaryota       Ascomycota         Eurotiomycetes
# 12371     Eukaryota    Basidiomycota        Tremellomycetes
# 12372     Eukaryota       Ascomycota        Dothideomycetes
# 12373     Eukaryota       Ascomycota        Dothideomycetes
# 12374      Bacteria   Proteobacteria    Gammaproteobacteria
# 12375     Eukaryota       Ascomycota        Dothideomycetes
# 12376     Eukaryota       Ascomycota        Sordariomycetes
# 12377  Unclassified     Unclassified           Unclassified
# 12378     Eukaryota       Ascomycota        Dothideomycetes
# 12379     Eukaryota       Ascomycota        Dothideomycetes
# 12380     Eukaryota       Ascomycota        Dothideomycetes
# 12381     Eukaryota       Ascomycota        Dothideomycetes
# 12382      Bacteria   Proteobacteria    Gammaproteobacteria
# 12383     Eukaryota       Ascomycota        Dothideomycetes
# 12384     Eukaryota       Ascomycota        Dothideomycetes
# 12385     Eukaryota       Ascomycota        Dothideomycetes
# 12386     Eukaryota       Ascomycota        Dothideomycetes
# 12387     Eukaryota    Basidiomycota        Tremellomycetes
# 12388      Bacteria   Proteobacteria    Gammaproteobacteria
# 12389     Eukaryota       Ascomycota        Dothideomycetes
# 12390     Eukaryota       Ascomycota        Dothideomycetes
# 12391     Eukaryota     Streptophyta             Liliopsida
# 12392     Eukaryota     Streptophyta             Liliopsida
# 12393     Eukaryota       Ascomycota        Sordariomycetes
# 12394     Eukaryota       Ascomycota        Dothideomycetes
# 12395     Eukaryota       Ascomycota        Dothideomycetes
# 12396     Eukaryota       Ascomycota        Dothideomycetes
# 12397     Eukaryota       Ascomycota        Sordariomycetes
#
#                    order                family              genus  \
# 0           Unclassified          Unclassified       Unclassified
# 1        Pseudomonadales      Pseudomonadaceae        Pseudomonas
# 2            Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 3            Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 4                 Poales               Poaceae           Triticum
# 5         Cyclophyllidea       Hymenolepididae        Hymenolepis
# 6            Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 7            Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 8      Campylobacterales    Campylobacteraceae      Campylobacter
# 9      Botryosphaeriales    Botryosphaeriaceae           Diplodia
# 10      Enterobacterales    Enterobacteriaceae        Escherichia
# 11              Liliales           Smilacaceae             Smilax
# 12          Pleosporales     Leptosphaeriaceae      Leptosphaeria
# 13           Pucciniales          Pucciniaceae           Puccinia
# 14      Enterobacterales           Erwiniaceae            Erwinia
# 15              Primates        Cheirogaleidae         Microcebus
# 16           Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 17           Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 18                Poales               Poaceae            Hordeum
# 19           Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 20           Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 21           Hymenoptera                Apidae               Apis
# 22           Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 23           Capnodiales    Mycosphaerellaceae       Zymoseptoria
# 24       Pseudomonadales      Pseudomonadaceae        Pseudomonas
# 25                Poales               Poaceae           Triticum
# 26               Diptera           Tephritidae         Bactrocera
# 27          Pleosporales         Pleosporaceae         Alternaria
# 28       Pseudomonadales      Pseudomonadaceae        Pseudomonas
# 29       Pseudomonadales      Pseudomonadaceae        Pseudomonas
# ...                  ...                   ...                ...
# 12368   Enterobacterales           Erwiniaceae            Pantoea
# 12369         Onygenales           Onygenaceae       Uncinocarpus
# 12370         Eurotiales        Aspergillaceae        Aspergillus
# 12371        Tremellales       Cryptococcaceae       Cryptococcus
# 12372       Pleosporales         Pleosporaceae         Alternaria
# 12373       Pleosporales     Leptosphaeriaceae      Leptosphaeria
# 12374    Pseudomonadales      Pseudomonadaceae        Pseudomonas
# 12375       Pleosporales         Pleosporaceae         Alternaria
# 12376        Sordariales         Chaetomiaceae          Thielavia
# 12377       Unclassified          Unclassified       Unclassified
# 12378       Pleosporales         Pleosporaceae         Alternaria
# 12379       Pleosporales         Pleosporaceae          Bipolaris
# 12380       Pleosporales     Leptosphaeriaceae      Leptosphaeria
# 12381       Pleosporales         Pleosporaceae        Pyrenophora
# 12382   Enterobacterales    Enterobacteriaceae        Escherichia
# 12383       Pleosporales    Didymosphaeriaceae  Paraphaeosphaeria
# 12384       Pleosporales         Pleosporaceae         Alternaria
# 12385       Pleosporales         Pleosporaceae         Alternaria
# 12386       Pleosporales         Pleosporaceae       Setosphaeria
# 12387        Tremellales   Trimorphomycetaceae     Trimorphomyces
# 12388    Pseudomonadales      Pseudomonadaceae        Pseudomonas
# 12389       Pleosporales         Pleosporaceae         Alternaria
# 12390       Pleosporales         Pleosporaceae         Alternaria
# 12391             Poales               Poaceae           Triticum
# 12392             Poales               Poaceae       Brachypodium
# 12393      Glomerellales  Plectosphaerellaceae       Verticillium
# 12394       Pleosporales         Pleosporaceae       Setosphaeria
# 12395       Pleosporales         Pleosporaceae         Alternaria
# 12396       Pleosporales         Pleosporaceae         Alternaria
# 12397      Glomerellales  Plectosphaerellaceae       Verticillium
#
#                                       species  Flowcell
# 0                 Cloning vector lambda TXF97      run1
# 1                     Pseudomonas viridiflava      run1
# 2                        Zymoseptoria tritici      run1
# 3                        Zymoseptoria tritici      run1
# 4                           Triticum aestivum      run1
# 5                            Hymenolepis nana      run1
# 6                        Zymoseptoria tritici      run1
# 7                        Zymoseptoria tritici      run1
# 8                    Campylobacter sp. RM6137      run1
# 9                          Diplodia corticola      run1
# 10                           Escherichia coli      run1
# 11                               Smilax china      run1
# 12                     Leptosphaeria maculans      run1
# 13                       Puccinia striiformis      run1
# 14                          Erwinia amylovora      run1
# 15                         Microcebus murinus      run1
# 16                       Zymoseptoria tritici      run1
# 17                       Zymoseptoria tritici      run1
# 18                            Hordeum vulgare      run1
# 19                       Zymoseptoria tritici      run1
# 20                       Zymoseptoria tritici      run1
# 21                                Apis florea      run1
# 22                       Zymoseptoria tritici      run1
# 23                       Zymoseptoria tritici      run1
# 24                       Pseudomonas syringae      run1
# 25                          Triticum aestivum      run1
# 26                       Bactrocera latifrons      run1
# 27                       Alternaria alternata      run1
# 28                       Pseudomonas syringae      run1
# 29                       Pseudomonas syringae      run1
# ...                                       ...       ...
# 12368                     Pantoea agglomerans  FAH05731
# 12369                     Uncinocarpus reesii  FAH05731
# 12370                   Aspergillus aculeatus  FAH05731
# 12371                Cryptococcus amylolentus  FAH05731
# 12372                    Alternaria alternata  FAH05731
# 12373                  Leptosphaeria maculans  FAH05731
# 12374  Pseudomonas syringae group genomosp. 3  FAH05731
# 12375                    Alternaria alternata  FAH05731
# 12376                    Thielavia terrestris  FAH05731
# 12377             Cloning vector lambda TXF97  FAH05731
# 12378                    Alternaria alternata  FAH05731
# 12379                   Bipolaris sorokiniana  FAH05731
# 12380                  Leptosphaeria maculans  FAH05731
# 12381                       Pyrenophora teres  FAH05731
# 12382                        Escherichia coli  FAH05731
# 12383             Paraphaeosphaeria sporulosa  FAH05731
# 12384                    Alternaria alternata  FAH05731
# 12385                    Alternaria alternata  FAH05731
# 12386                    Setosphaeria turcica  FAH05731
# 12387            Trimorphomyces papilionaceus  FAH05731
# 12388                 Pseudomonas viridiflava  FAH05731
# 12389                    Alternaria alternata  FAH05731
# 12390                    Alternaria alternata  FAH05731
# 12391                       Triticum aestivum  FAH05731
# 12392                 Brachypodium distachyon  FAH05731
# 12393                    Verticillium dahliae  FAH05731
# 12394                    Setosphaeria turcica  FAH05731
# 12395                    Alternaria alternata  FAH05731
# 12396                    Alternaria alternata  FAH05731
# 12397                   Verticillium alfalfae  FAH05731
#
# [12398 rows x 11 columns]

# %%
#Defines a function to make manual adjustments to the NCBI taxonomic sorting
def manually_adjust_ncbi_taxonomy(rank_select, entry_select, ranks_to_edit, new_entry):
    """Select dataframe entries to edit by a specific rank (rank_select) 
    and entry related to that rank (entry_select), 
    provide a list of ranks to edit for those selected entries (ranks_to_edit),
    replace these ranks with a new entry (new_entry)"""
    if entry_select in list(joint_taxa_df[rank_select].unique()):
        selection = (joint_taxa_df[rank_select] == entry_select)
        selected_tax_ranks = ranks_to_edit
        for ranks in selected_tax_ranks:
            joint_taxa_df[ranks][selection] = new_entry

# %%
manually_adjust_ncbi_taxonomy('species', 
                            'Cloning vector lambda TXF97', 
                            ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus'], 
                            'Cloning vector lambda TXF97')

manually_adjust_ncbi_taxonomy('superkingdom', 
                            'Viruses', 
                            ['phylum', 'class'], 
                            'dsDNA viruses, no RNA stage')

# %%
#count pivot table of dataframe with taxonomic columns: 
#rows - rank names, columns - barcode, sorted by desired class
def generate_ncbi_taxonomy_pivot(tax_df, rank, bcs, num):
    """From tax_df, generate a pivot table listing num rank counts, sorted by bcs"""
    pivot_table = tax_df.pivot_table(values='order', 
                                            index=rank, 
                                            columns='barcode_arrangement', 
                                            aggfunc='count', 
                                            fill_value=0, 
                                            margins=True)
    pivot_table.columns.name = None
    return pivot_table.sort_values(bcs, axis=0, ascending=False).head(n=num)

# %%
generate_ncbi_taxonomy_pivot(joint_taxa_df, 'family','barcode04',20)
# Out:
#                     barcode01  barcode02  barcode03  barcode04  barcode05  \
# family
# All                    2517.0     4818.0      363.0     2235.0     2465.0
# Pseudomonadaceae       1800.0     2547.0      152.0     1335.0     1494.0
# Pleosporaceae            59.0      500.0       45.0      191.0      266.0
# Sphingomonadaceae         2.0      299.0        6.0       94.0      108.0
# Poaceae                  20.0       39.0       27.0       65.0       58.0
# Enterobacteriaceae       78.0       84.0       18.0       61.0       15.0
# Hymenobacteraceae         1.0      124.0        4.0       54.0       37.0
# Mycosphaerellaceae       13.0      195.0        3.0       51.0       41.0
# Microbacteriaceae         7.0      260.0       15.0       42.0       47.0
# Leptosphaeriaceae         9.0       64.0        8.0       26.0       36.0
# Erwiniaceae             260.0       41.0        0.0       24.0       19.0
# Unclassified              7.0       31.0        3.0       16.0       13.0
# Oxalobacteraceae         25.0       35.0        0.0       16.0       49.0
# Cryptococcaceae           4.0       12.0        2.0       10.0       12.0
# Siphoviridae              0.0        2.0        1.0        9.0        2.0
# Pucciniaceae             76.0       27.0        0.0        8.0        6.0
# Nocardiaceae              2.0       52.0        0.0        8.0        1.0
# Burkholderiaceae          4.0       12.0        2.0        7.0       19.0
# Culicidae                 1.0        1.0        1.0        7.0        2.0
# Paenibacillaceae          1.0       10.0        0.0        6.0        4.0
#
#                         All
# family
# All                 12398.0
# Pseudomonadaceae     7328.0
# Pleosporaceae        1061.0
# Sphingomonadaceae     509.0
# Poaceae               209.0
# Enterobacteriaceae    256.0
# Hymenobacteraceae     220.0
# Mycosphaerellaceae    303.0
# Microbacteriaceae     371.0
# Leptosphaeriaceae     143.0
# Erwiniaceae           344.0
# Unclassified           70.0
# Oxalobacteraceae      125.0
# Cryptococcaceae        40.0
# Siphoviridae           14.0
# Pucciniaceae          117.0
# Nocardiaceae           63.0
# Burkholderiaceae       44.0
# Culicidae              12.0
# Paenibacillaceae       21.0

# %%
# % pivot table of dataframe with taxonomic columns: 
#rows - rank names, columns - barcode, sorted by desired class
def generate_ncbi_taxonomy_pivot_pc(tax_df, rank, bcs, num):
    """From tax_df, generate a pivot table listing num rank %, sorted ascending by bcs"""
    pivot_table_pc = tax_df.pivot_table(values='order', 
                                            index=rank, 
                                            columns='barcode_arrangement', 
                                            aggfunc='count', 
                                            fill_value=0, 
                                            margins=True)
    pivot_table_pc.columns.name = None
    
    for brcs in pivot_table_pc.columns:
        pivot_table_pc[str(brcs) + '%'] = pivot_table_pc[brcs].apply(lambda x: (x / pivot_table_pc[brcs].loc['All'])*100)
    for brcs in pivot_table_pc.columns:
        if '%' not in brcs:
            pivot_table_pc.drop(brcs, axis=1, inplace=True)
    pivot_table_pc.drop('All', axis=0, inplace=True)

    pivot_table_pc2 = pivot_table_pc.sort_values(str(bcs) + '%', axis=0, ascending=False)
    return pivot_table_pc2.applymap(lambda x: '%.3f' % x).head(n=num)

# %%
generate_ncbi_taxonomy_pivot_pc(joint_taxa_df, 'species', 'barcode04', 20)
# Out:
#                             barcode01% barcode02% barcode03% barcode04%  \
# species
# Pseudomonas syringae            56.297     35.596     10.193     40.984
# Pseudomonas viridiflava          1.112      3.342      5.234      7.114
# Alternaria alternata             1.629      7.721      7.989      6.398
# Pseudomonas poae                 6.595      6.932      9.642      6.219
# Escherichia coli                 0.675      1.225      4.683      2.371
# Zymoseptoria tritici             0.477      3.923      0.826      2.148
# Hymenobacter sp. PAMC 26554      0.000      1.494      0.275      1.566
# Sphingomonas taxi                0.000      1.847      0.551      1.521
# Triticum aestivum                0.318      0.208      4.959      1.342
# Pseudomonas cerasi               1.311      2.262      0.275      0.984
# Pantoea agglomerans              0.556      0.104      0.000      0.940
# Leptosphaeria biglobosa          0.159      0.955      1.653      0.805
# Sphingomonas panacis             0.000      0.643      0.000      0.626
# Setosphaeria turcica             0.238      0.560      1.102      0.582
# Pseudomonas fluorescens          0.358      0.477      3.030      0.582
# Pseudomonas savastanoi           1.192      0.457      0.000      0.537
# Aegilops speltoides              0.040      0.062      0.275      0.447
# Curtobacterium sp. 9128          0.040      0.208      0.275      0.447
# Pseudomonas amygdali             0.199      0.208      0.275      0.358
# Leptosphaeria maculans           0.199      0.374      0.551      0.358
#
#                             barcode05%    All%
# species
# Pseudomonas syringae            25.355  37.990
# Pseudomonas viridiflava          2.961   3.549
# Alternaria alternata             7.870   6.283
# Pseudomonas poae                20.284   9.469
# Escherichia coli                 0.406   1.258
# Zymoseptoria tritici             1.501   2.331
# Hymenobacter sp. PAMC 26554      0.974   1.065
# Sphingomonas taxi                1.217   1.250
# Triticum aestivum                1.704   0.871
# Pseudomonas cerasi               0.609   1.452
# Pantoea agglomerans              0.325   0.387
# Leptosphaeria biglobosa          0.933   0.782
# Sphingomonas panacis             0.609   0.484
# Setosphaeria turcica             0.487   0.500
# Pseudomonas fluorescens          1.339   0.718
# Pseudomonas savastanoi           0.243   0.565
# Aegilops speltoides              0.041   0.129
# Curtobacterium sp. 9128          0.325   0.242
# Pseudomonas amygdali             0.243   0.242
# Leptosphaeria maculans           0.527   0.371

# %%
#Assesses number of barcodes, generates necessary number of plots (even) and relevant indexing system
ncbiblast_barcodes = list(joint_taxa_df['barcode_arrangement'].unique())
no_of_subplots = len(ncbiblast_barcodes)+1

# %%
#Always 2 columns, bc-count/2 rows 
no_of_subplots_pair = [int(no_of_subplots/2), 2]

#Produce pairs of indices correlating to the coordinates of the subplots
subplot_coordinates = list(product(range(no_of_subplots_pair[0]), range(no_of_subplots_pair[1])))
subplot_coordinates_list = [list(l) for l in subplot_coordinates]
subplot_coordinates_list_rows = [i[0] for i in subplot_coordinates_list]
subplot_coordinates_list_columns = [i[1] for i in subplot_coordinates_list]

fig, ax = plt.subplots(no_of_subplots_pair[1], no_of_subplots_pair[0], figsize=(20, 6))

# %%
subplot_coordinates
# Out:
# [(0, 0), (0, 1), (1, 0), (1, 1), (2, 0), (2, 1)]

# %%
def get_color(x):
    x = x%10
    return ('#%02X%02X%02X' % (int(plt.cm.tab10.colors[x][0]*255),int(plt.cm.tab10.colors[x][1]*255),int(plt.cm.tab10.colors[x][2]*255)))

def applyTaxPlotStyle(ax_ind1, ax_ind2, bcs, rank):
    labels = ''
    labels = tuple(generate_ncbi_taxonomy_pivot_pc(joint_taxa_df, rank, bcs, 10)[bcs + '%'].index)
    y_pos = ''
    y_pos = np.arange(len(labels))
    sizes = ''
    sizes = tuple([float(i) for i in generate_ncbi_taxonomy_pivot_pc(joint_taxa_df, rank, bcs, 10)[bcs + '%']])
    
    ax[ax_ind1, ax_ind2].barh(y_pos, sizes, align='center', alpha=0.4, color=get_color(2*ax_ind2 + ax_ind1))
    ax[ax_ind1, ax_ind2].set_yticks(y_pos)
    ax[ax_ind1, ax_ind2].set_yticklabels(labels)
    ax[ax_ind1, ax_ind2].tick_params(top="off", right="off", left="off")
    ax[ax_ind1, ax_ind2].set_xlabel('% Total Reads Hitting NCBI')
    ax[ax_ind1, ax_ind2].set_xticks(range(0, 110, 10))
    ax[ax_ind1, ax_ind2].set_title(bcs)
    ax[ax_ind1, ax_ind2].invert_yaxis()
    ax[ax_ind1, ax_ind2].grid(b=None, which='major', axis='x', linestyle='dashed', linewidth=0.2)
    ax[ax_ind1, ax_ind2].annotate('E = 0.00001', 
             xy=(1.06, 0.3), xycoords='axes fraction', fontsize=10, xytext=(-20, -30), textcoords='offset points', 
             ha='right', va='bottom')
    
def generateTaxSubplots(search_rank):
    for ax_ind1, ax_ind2, bcs, in zip(subplot_coordinates_list_columns, subplot_coordinates_list_rows, ncbiblast_barcodes):
        applyTaxPlotStyle(ax_ind1, ax_ind2, bcs, search_rank)    

    if len(list(joint_taxa_df['barcode_arrangement'].unique())) != 0:
        plt.delaxes(ax[subplot_coordinates_list_columns[-1], subplot_coordinates_list_rows[-1]])
    
    plt.suptitle('Reads Hitting NCBI Database - % By ' + str(search_rank).title() + ' By Barcode', 
             fontsize='x-large',
             y=1.02,
             fontweight="bold")
    
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1.4, hspace=0.4)
    plt.tight_layout()
    
    plt.savefig(BASEDIR + '/figures/' + 'figure3.png', bbox_inches='tight')
    plt.show()

# %%
fig, ax = plt.subplots(no_of_subplots_pair[1], no_of_subplots_pair[0], figsize=(20, 6))
generateTaxSubplots('family')
